# %%
# Simulation of an M/M/n queue

import simpy
import random
import numpy as np
import matplotlib.pyplot as plt

servers = 1
customers = 30000
runtime = 10000
arrivals = 2
processing = 3

timing = []
waitingtime = []
utilization = []

def source(env, counter):
    for i in range(customers):
        c = customer(env, 'Customer%02d' % i, counter)
        env.process(c) # Add new customer process
        t = random.expovariate(arrivals)
        yield env.timeout(t) # Wait until interarrival time has passed
        
def customer(env, name, counter):
    arrive = env.now
    print('%7.4f %s: Arrival ' % (arrive, name))
    
    with counter.request() as req:
        # Wait for the counter to be free
        yield req
        
        wait = env.now - arrive    
        waitingtime.append(wait)
        # We got to the counter
        print('%7.4f %s: Waited %6.3f' % (env.now, name, wait))
        tib = random.expovariate(processing) # Processing time
        utilization.append(tib)
        yield env.timeout(tib) # Wait until processing is done
        
        print('%7.4f %s: Finished' % (env.now, name))
        timing.append(env.now)

env = simpy.Environment()

counter = simpy.Resource(env, capacity=servers)
env.process(source(env,counter))
env.run(until=runtime)

print("Utilization: "+str(np.sum(utilization)/runtime/servers))
print("Average waiting time: "+str(np.mean(waitingtime)))

utu = []
wtu = []
for k in range(len(timing)):
  utu.append(np.sum(utilization[:k+1])/timing[k]/servers)
  wtu.append(np.sum(waitingtime[:k+1])/(k+1))  
 
plt.plot(timing,utu,'bs')
plt.xlabel("Time")
plt.ylabel("Utilization")
plt.show()

plt.plot(timing,wtu,'r^')
plt.xlabel("Time")
plt.ylabel("Average waiting time")
plt.show()
# Out:
#  0.0000 Customer00: Arrival
#  0.0000 Customer00: Waited  0.000
#  0.0576 Customer00: Finished
#  1.2170 Customer01: Arrival
#  1.2170 Customer01: Waited  0.000
#  1.3077 Customer02: Arrival
#  2.1758 Customer01: Finished
#  2.1758 Customer02: Waited  0.868
#  2.3821 Customer02: Finished
#  2.5229 Customer03: Arrival
#  2.5229 Customer03: Waited  0.000
#  2.9433 Customer04: Arrival
#  3.5212 Customer05: Arrival
#  3.6746 Customer03: Finished
#  3.6746 Customer04: Waited  0.731
#  4.1178 Customer06: Arrival
#  4.1990 Customer04: Finished
#  4.1990 Customer05: Waited  0.678
#  4.8146 Customer07: Arrival
#  4.9958 Customer05: Finished
#  4.9958 Customer06: Waited  0.878
#  5.0282 Customer08: Arrival
#  5.6305 Customer06: Finished
#  5.6305 Customer07: Waited  0.816
#  5.6305 Customer07: Finished
#  5.6305 Customer08: Waited  0.602
#  5.7199 Customer08: Finished
#  6.6438 Customer09: Arrival
#  6.6438 Customer09: Waited  0.000
#  6.6791 Customer10: Arrival
#  6.7287 Customer11: Arrival
#  6.8098 Customer12: Arrival
#  6.9404 Customer09: Finished
#  6.9404 Customer10: Waited  0.261
#  6.9647 Customer13: Arrival
#  7.0396 Customer10: Finished
#  7.0396 Customer11: Waited  0.311
#  7.2071 Customer14: Arrival
#  7.2162 Customer11: Finished
#  7.2162 Customer12: Waited  0.406
#  7.6647 Customer12: Finished
#  7.6647 Customer13: Waited  0.700
#  8.1716 Customer13: Finished
#  8.1716 Customer14: Waited  0.965
#  8.2795 Customer14: Finished
#  8.3801 Customer15: Arrival
#  8.3801 Customer15: Waited  0.000
#  8.5522 Customer15: Finished
#  8.8244 Customer16: Arrival
#  8.8244 Customer16: Waited  0.000
#  8.9408 Customer16: Finished
#  9.2467 Customer17: Arrival
#  9.2467 Customer17: Waited  0.000
#  9.5831 Customer18: Arrival
#  9.6394 Customer19: Arrival
#  9.6560 Customer17: Finished
#  9.6560 Customer18: Waited  0.073
# 10.5109 Customer18: Finished
# 10.5109 Customer19: Waited  0.871
# 10.6816 Customer20: Arrival
# 10.7805 Customer19: Finished
# 10.7805 Customer20: Waited  0.099
# 11.1398 Customer20: Finished
# 11.2723 Customer21: Arrival
# 11.2723 Customer21: Waited  0.000
# 11.4700 Customer22: Arrival
# 12.2930 Customer21: Finished
# 12.2930 Customer22: Waited  0.823
# 12.5296 Customer23: Arrival
# 12.8043 Customer22: Finished
# 12.8043 Customer23: Waited  0.275
# 12.8841 Customer23: Finished
# 13.0900 Customer24: Arrival
# 13.0900 Customer24: Waited  0.000
# 13.4373 Customer24: Finished
# 14.2618 Customer25: Arrival
# 14.2618 Customer25: Waited  0.000
# 14.2939 Customer25: Finished
# 14.7196 Customer26: Arrival
# 14.7196 Customer26: Waited  0.000
# 14.7753 Customer26: Finished
# 14.9355 Customer27: Arrival
# 14.9355 Customer27: Waited  0.000
# 14.9846 Customer27: Finished
# 15.1391 Customer28: Arrival
# 15.1391 Customer28: Waited  0.000
# 15.1922 Customer29: Arrival
# 15.2449 Customer28: Finished
# 15.2449 Customer29: Waited  0.053
# 15.9319 Customer29: Finished
# 16.2434 Customer30: Arrival
# 16.2434 Customer30: Waited  0.000
# 16.3971 Customer30: Finished
# 16.5499 Customer31: Arrival
# 16.5499 Customer31: Waited  0.000
# 16.7946 Customer31: Finished
# 17.0350 Customer32: Arrival
# 17.0350 Customer32: Waited  0.000
# 17.0572 Customer33: Arrival
# 17.0894 Customer32: Finished
# 17.0894 Customer33: Waited  0.032
# 17.5698 Customer33: Finished
# 18.5636 Customer34: Arrival
# 18.5636 Customer34: Waited  0.000
# 18.8796 Customer34: Finished
# 19.2935 Customer35: Arrival
# 19.2935 Customer35: Waited  0.000
# 19.3137 Customer36: Arrival
# 19.5058 Customer35: Finished
# 19.5058 Customer36: Waited  0.192
# 19.5497 Customer37: Arrival
# 19.8432 Customer38: Arrival
# 20.4180 Customer36: Finished
# 20.4180 Customer37: Waited  0.868
# 20.4180 Customer37: Finished
# 20.4180 Customer38: Waited  0.575
# 20.5789 Customer39: Arrival
# 20.6059 Customer40: Arrival
# 20.7645 Customer38: Finished
# 20.7645 Customer39: Waited  0.186
# 20.9608 Customer39: Finished
# 20.9608 Customer40: Waited  0.355
# 21.0254 Customer40: Finished
# 21.1275 Customer41: Arrival
# 21.1275 Customer41: Waited  0.000
# 21.3518 Customer42: Arrival
# 21.6099 Customer43: Arrival
# 21.6909 Customer44: Arrival
# 21.7051 Customer45: Arrival
# 22.0366 Customer41: Finished
# 22.0366 Customer42: Waited  0.685
# 22.1865 Customer42: Finished
# 22.1865 Customer43: Waited  0.577
# 22.3617 Customer46: Arrival
# 22.5099 Customer43: Finished
# 22.5099 Customer44: Waited  0.819
# 22.7090 Customer47: Arrival
# 24.0405 Customer44: Finished
# 24.0405 Customer45: Waited  2.335
# 24.1507 Customer45: Finished
# 24.1507 Customer46: Waited  1.789
# 24.3146 Customer48: Arrival
# 24.6046 Customer46: Finished
# 24.6046 Customer47: Waited  1.896
# 24.9439 Customer49: Arrival
# 25.6558 Customer47: Finished
# 25.6558 Customer48: Waited  1.341
# 25.8564 Customer50: Arrival
# 26.0390 Customer51: Arrival
# 26.9949 Customer52: Arrival
# 27.0330 Customer48: Finished
# 27.0330 Customer49: Waited  2.089
# 27.0733 Customer49: Finished
# 27.0733 Customer50: Waited  1.217
# 27.1481 Customer50: Finished
# 27.1481 Customer51: Waited  1.109
# 27.3782 Customer53: Arrival
# 27.4056 Customer54: Arrival
# 27.4067 Customer55: Arrival
# 27.4104 Customer51: Finished
# 27.4104 Customer52: Waited  0.415
# 27.6213 Customer56: Arrival
# 27.6862 Customer52: Finished
# 27.6862 Customer53: Waited  0.308
# 27.8261 Customer53: Finished
# 27.8261 Customer54: Waited  0.420
# 28.0241 Customer54: Finished
# 28.0241 Customer55: Waited  0.617
# 28.3818 Customer55: Finished
# 28.3818 Customer56: Waited  0.761
# 28.4083 Customer56: Finished
# 28.4371 Customer57: Arrival
# 28.4371 Customer57: Waited  0.000
# 28.6414 Customer57: Finished
# 29.2848 Customer58: Arrival
# 29.2848 Customer58: Waited  0.000
# 29.7052 Customer58: Finished
# 30.4067 Customer59: Arrival
# 30.4067 Customer59: Waited  0.000
# 30.7023 Customer60: Arrival
# 30.7977 Customer61: Arrival
# 31.0074 Customer62: Arrival
# 31.0788 Customer59: Finished
# 31.0788 Customer60: Waited  0.376
# 31.0929 Customer60: Finished
# 31.0929 Customer61: Waited  0.295
# 31.5093 Customer63: Arrival
# 31.5480 Customer61: Finished
# 31.5480 Customer62: Waited  0.541
# 32.2624 Customer62: Finished
# 32.2624 Customer63: Waited  0.753
# 32.3030 Customer63: Finished
# 32.5001 Customer64: Arrival
# 32.5001 Customer64: Waited  0.000
# 32.5224 Customer65: Arrival
# 32.5386 Customer64: Finished
# 32.5386 Customer65: Waited  0.016
# 32.7952 Customer66: Arrival
# 32.8158 Customer67: Arrival
# 32.9392 Customer65: Finished
# 32.9392 Customer66: Waited  0.144
# 33.0650 Customer68: Arrival
# 33.1356 Customer66: Finished
# 33.1356 Customer67: Waited  0.320
# 33.3230 Customer67: Finished
# 33.3230 Customer68: Waited  0.258
# 33.6087 Customer69: Arrival
# 33.6141 Customer68: Finished
# 33.6141 Customer69: Waited  0.005
# 33.6492 Customer70: Arrival
# 34.0113 Customer69: Finished
# 34.0113 Customer70: Waited  0.362
# 34.5494 Customer70: Finished
# 35.9181 Customer71: Arrival
# 35.9181 Customer71: Waited  0.000
# 36.1163 Customer71: Finished
# 37.7174 Customer72: Arrival
# 37.7174 Customer72: Waited  0.000
# 37.7835 Customer73: Arrival
# 37.8270 Customer74: Arrival
# 37.9527 Customer72: Finished
# 37.9527 Customer73: Waited  0.169
# 38.0193 Customer73: Finished
# 38.0193 Customer74: Waited  0.192
# 38.7316 Customer75: Arrival
# 38.7881 Customer74: Finished
# 38.7881 Customer75: Waited  0.057
# 39.1717 Customer75: Finished
# 40.3202 Customer76: Arrival
# 40.3202 Customer76: Waited  0.000
# 40.5951 Customer77: Arrival
# 41.0979 Customer78: Arrival
# 41.1557 Customer79: Arrival
# 41.3272 Customer76: Finished
# 41.3272 Customer77: Waited  0.732
# 42.2203 Customer80: Arrival
# 42.3786 Customer81: Arrival
# 42.5349 Customer77: Finished
# 42.5349 Customer78: Waited  1.437
# 42.8379 Customer82: Arrival
# 42.9068 Customer78: Finished
# 42.9068 Customer79: Waited  1.751
# 43.1822 Customer79: Finished
# 43.1822 Customer80: Waited  0.962
# 43.3398 Customer80: Finished
# 43.3398 Customer81: Waited  0.961
# 43.5138 Customer83: Arrival
# 43.7606 Customer81: Finished
# 43.7606 Customer82: Waited  0.923
# 43.7967 Customer84: Arrival
# 43.8797 Customer85: Arrival
# 44.3564 Customer82: Finished
# 44.3564 Customer83: Waited  0.843
# 44.4858 Customer86: Arrival
# 44.5003 Customer83: Finished
# 44.5003 Customer84: Waited  0.704
# 44.6023 Customer84: Finished
# 44.6023 Customer85: Waited  0.723
# 44.6475 Customer87: Arrival
# 45.4466 Customer88: Arrival
# 45.5344 Customer85: Finished
# 45.5344 Customer86: Waited  1.049
# 45.9079 Customer89: Arrival
# 45.9102 Customer90: Arrival
# 46.2754 Customer91: Arrival
# 46.6209 Customer86: Finished
# 46.6209 Customer87: Waited  1.973
# 46.6468 Customer87: Finished
# 46.6468 Customer88: Waited  1.200
# 46.6829 Customer88: Finished
# 46.6829 Customer89: Waited  0.775
# 46.7386 Customer89: Finished
# 46.7386 Customer90: Waited  0.828
# 46.7652 Customer90: Finished
# 46.7652 Customer91: Waited  0.490
# 47.0040 Customer91: Finished
# 47.3545 Customer92: Arrival
# 47.3545 Customer92: Waited  0.000
# 47.5523 Customer92: Finished
# 47.8713 Customer93: Arrival
# 47.8713 Customer93: Waited  0.000
# 48.6671 Customer94: Arrival
# 48.9014 Customer95: Arrival
# 49.4695 Customer93: Finished
# 49.4695 Customer94: Waited  0.802
# 50.0246 Customer94: Finished
# 50.0246 Customer95: Waited  1.123
# 50.0920 Customer95: Finished
# 50.1065 Customer96: Arrival
# 50.1065 Customer96: Waited  0.000
# 50.2241 Customer96: Finished
# 51.2880 Customer97: Arrival
# 51.2880 Customer97: Waited  0.000
# 51.3695 Customer98: Arrival
# 51.4086 Customer97: Finished
# 51.4086 Customer98: Waited  0.039
# 51.5344 Customer99: Arrival
# 51.5895 Customer100: Arrival
# 51.6781 Customer98: Finished
# 51.6781 Customer99: Waited  0.144
# 51.9707 Customer101: Arrival
# 52.1775 Customer99: Finished
# 52.1775 Customer100: Waited  0.588
# 52.2259 Customer102: Arrival
# 52.8282 Customer100: Finished
# 52.8282 Customer101: Waited  0.858
# 53.4720 Customer103: Arrival
# 53.5243 Customer101: Finished
# 53.5243 Customer102: Waited  1.298
# 53.6084 Customer104: Arrival
# 53.6218 Customer102: Finished
# 53.6218 Customer103: Waited  0.150
# 53.7658 Customer103: Finished
# 53.7658 Customer104: Waited  0.157
# 53.7997 Customer105: Arrival
# 53.9334 Customer104: Finished
# 53.9334 Customer105: Waited  0.134
# 53.9796 Customer106: Arrival
# 54.4389 Customer107: Arrival
# 54.5793 Customer108: Arrival
# 54.5892 Customer109: Arrival
# 54.7852 Customer110: Arrival
# 55.0818 Customer105: Finished
# 55.0818 Customer106: Waited  1.102
# 55.3599 Customer106: Finished
# 55.3599 Customer107: Waited  0.921
# 55.3649 Customer111: Arrival
# 55.6773 Customer112: Arrival
# 55.7067 Customer107: Finished
# 55.7067 Customer108: Waited  1.127
# 56.0314 Customer113: Arrival
# 56.0664 Customer108: Finished
# 56.0664 Customer109: Waited  1.477
# 56.2258 Customer114: Arrival
# 56.8277 Customer109: Finished
# 56.8277 Customer110: Waited  2.043
# 57.0680 Customer115: Arrival
# 57.0835 Customer110: Finished
# 57.0835 Customer111: Waited  1.719
# 57.2396 Customer116: Arrival
# 57.6055 Customer111: Finished
# 57.6055 Customer112: Waited  1.928
# 57.6826 Customer117: Arrival
# 58.0081 Customer118: Arrival
# 58.2147 Customer112: Finished
# 58.2147 Customer113: Waited  2.183
# 58.2391 Customer113: Finished
# 58.2391 Customer114: Waited  2.013
# 58.4208 Customer114: Finished
# 58.4208 Customer115: Waited  1.353
# 58.4797 Customer115: Finished
# 58.4797 Customer116: Waited  1.240
# 58.5147 Customer116: Finished
# 58.5147 Customer117: Waited  0.832
# 59.5663 Customer117: Finished
# 59.5663 Customer118: Waited  1.558
# 59.9524 Customer119: Arrival
# 60.0986 Customer118: Finished
# 60.0986 Customer119: Waited  0.146
# 60.3959 Customer119: Finished
# 60.6806 Customer120: Arrival
# 60.6806 Customer120: Waited  0.000
# 60.9835 Customer120: Finished
# 61.4604 Customer121: Arrival
# 61.4604 Customer121: Waited  0.000
# 61.7839 Customer122: Arrival
# 61.8476 Customer123: Arrival
# 61.9876 Customer124: Arrival
# 62.0762 Customer121: Finished
# 62.0762 Customer122: Waited  0.292
# 62.3931 Customer125: Arrival
# 62.5265 Customer122: Finished
# 62.5265 Customer123: Waited  0.679
# 62.5431 Customer123: Finished
# 62.5431 Customer124: Waited  0.555
# 62.5658 Customer126: Arrival
# 62.7012 Customer124: Finished
# 62.7012 Customer125: Waited  0.308
# 62.8690 Customer127: Arrival
# 62.8925 Customer125: Finished
# 62.8925 Customer126: Waited  0.327
# 63.2664 Customer128: Arrival
# 63.3868 Customer126: Finished
# 63.3868 Customer127: Waited  0.518
# 63.6136 Customer129: Arrival
# 63.7083 Customer127: Finished
# 63.7083 Customer128: Waited  0.442
# 63.8198 Customer130: Arrival
# 63.8430 Customer128: Finished
# 63.8430 Customer129: Waited  0.229
# 64.2460 Customer129: Finished
# 64.2460 Customer130: Waited  0.426
# 64.3091 Customer131: Arrival
# 64.4506 Customer130: Finished
# 64.4506 Customer131: Waited  0.142
# 64.5424 Customer131: Finished
# 64.7736 Customer132: Arrival
# 64.7736 Customer132: Waited  0.000
# 64.8432 Customer132: Finished
# 65.0021 Customer133: Arrival
# 65.0021 Customer133: Waited  0.000
# 65.3459 Customer134: Arrival
# 65.7143 Customer135: Arrival
# 65.7804 Customer136: Arrival
# 66.0051 Customer133: Finished
# 66.0051 Customer134: Waited  0.659
# 66.0979 Customer137: Arrival
# 66.1943 Customer138: Arrival
# 66.2288 Customer134: Finished
# 66.2288 Customer135: Waited  0.514
# 66.5056 Customer139: Arrival
# 66.9902 Customer140: Arrival
# 67.4049 Customer141: Arrival
# 67.5358 Customer142: Arrival
# 67.6028 Customer135: Finished
# 67.6028 Customer136: Waited  1.822
# 67.6792 Customer136: Finished
# 67.6792 Customer137: Waited  1.581
# 68.0912 Customer137: Finished
# 68.0912 Customer138: Waited  1.897
# 68.1724 Customer138: Finished
# 68.1724 Customer139: Waited  1.667
# 68.2018 Customer143: Arrival
# 68.2539 Customer139: Finished
# 68.2539 Customer140: Waited  1.264
# 68.3572 Customer144: Arrival
# 68.6006 Customer145: Arrival
# 68.7898 Customer140: Finished
# 68.7898 Customer141: Waited  1.385
# 68.8718 Customer141: Finished
# 68.8718 Customer142: Waited  1.336
# 69.0672 Customer142: Finished
# 69.0672 Customer143: Waited  0.865
# 69.2381 Customer143: Finished
# 69.2381 Customer144: Waited  0.881
# 69.2697 Customer146: Arrival
# 69.2921 Customer147: Arrival
# 69.4434 Customer144: Finished
# 69.4434 Customer145: Waited  0.843
# 69.4529 Customer145: Finished
# 69.4529 Customer146: Waited  0.183
# 69.8152 Customer146: Finished
# 69.8152 Customer147: Waited  0.523
# 69.9439 Customer148: Arrival
# 70.1603 Customer147: Finished
# 70.1603 Customer148: Waited  0.216
# 70.3957 Customer148: Finished
# 70.4836 Customer149: Arrival
# 70.4836 Customer149: Waited  0.000
# 71.0595 Customer149: Finished
# 71.6270 Customer150: Arrival
# 71.6270 Customer150: Waited  0.000
# 72.4822 Customer150: Finished
# 72.9575 Customer151: Arrival
# 72.9575 Customer151: Waited  0.000
# 73.8227 Customer151: Finished
# 74.3088 Customer152: Arrival
# 74.3088 Customer152: Waited  0.000
# 74.5731 Customer153: Arrival
# 74.5918 Customer152: Finished
# 74.5918 Customer153: Waited  0.019
# 75.0064 Customer154: Arrival
# 75.1234 Customer155: Arrival
# 76.0048 Customer153: Finished
# 76.0048 Customer154: Waited  0.998
# 76.0609 Customer156: Arrival
# 76.1554 Customer157: Arrival
# 76.1884 Customer158: Arrival
# 76.2666 Customer159: Arrival
# 76.6423 Customer154: Finished
# 76.6423 Customer155: Waited  1.519
# 76.9589 Customer155: Finished
# 76.9589 Customer156: Waited  0.898
# 76.9688 Customer160: Arrival
# 76.9701 Customer156: Finished
# 76.9701 Customer157: Waited  0.815
# 77.0757 Customer157: Finished
# 77.0757 Customer158: Waited  0.887
# 77.5649 Customer161: Arrival
# 77.6464 Customer162: Arrival
# 77.8372 Customer158: Finished
# 77.8372 Customer159: Waited  1.571
# 78.1841 Customer159: Finished
# 78.1841 Customer160: Waited  1.215
# 78.3548 Customer163: Arrival
# 78.5343 Customer160: Finished
# 78.5343 Customer161: Waited  0.969
# 78.7866 Customer164: Arrival
# 78.9319 Customer161: Finished
# 78.9319 Customer162: Waited  1.285
# 78.9873 Customer165: Arrival
# 79.2466 Customer162: Finished
# 79.2466 Customer163: Waited  0.892
# 79.6941 Customer163: Finished
# 79.6941 Customer164: Waited  0.907
# 79.9016 Customer166: Arrival
# 80.0594 Customer164: Finished
# 80.0594 Customer165: Waited  1.072
# 80.1710 Customer167: Arrival
# 80.2524 Customer168: Arrival
# 80.2768 Customer165: Finished
# 80.2768 Customer166: Waited  0.375
# 80.3935 Customer166: Finished
# 80.3935 Customer167: Waited  0.222
# 80.5615 Customer167: Finished
# 80.5615 Customer168: Waited  0.309
# 80.6769 Customer168: Finished
# 80.8413 Customer169: Arrival
# 80.8413 Customer169: Waited  0.000
# 80.9397 Customer169: Finished
# 81.1368 Customer170: Arrival
# 81.1368 Customer170: Waited  0.000
# 81.3661 Customer171: Arrival
# 81.5992 Customer172: Arrival
# 81.6641 Customer170: Finished
# 81.6641 Customer171: Waited  0.298
# 81.6756 Customer171: Finished
# 81.6756 Customer172: Waited  0.076
# 81.8047 Customer172: Finished
# 81.9606 Customer173: Arrival
# 81.9606 Customer173: Waited  0.000
# 82.5272 Customer173: Finished
# 84.0438 Customer174: Arrival
# 84.0438 Customer174: Waited  0.000
# 84.0543 Customer175: Arrival
# 84.1457 Customer174: Finished
# 84.1457 Customer175: Waited  0.091
# 84.1914 Customer175: Finished
# 84.5138 Customer176: Arrival
# 84.5138 Customer176: Waited  0.000
# 84.6074 Customer176: Finished
# 84.7686 Customer177: Arrival
# 84.7686 Customer177: Waited  0.000
# 84.8634 Customer178: Arrival
# 85.0133 Customer179: Arrival
# 85.1147 Customer180: Arrival
# 85.2158 Customer181: Arrival
# 85.6218 Customer182: Arrival
# 85.7103 Customer177: Finished
# 85.7103 Customer178: Waited  0.847
# 85.8201 Customer183: Arrival
# 85.8256 Customer178: Finished
# 85.8256 Customer179: Waited  0.812
# 85.8257 Customer179: Finished
# 85.8257 Customer180: Waited  0.711
# 85.8519 Customer180: Finished
# 85.8519 Customer181: Waited  0.636
# 86.1579 Customer181: Finished
# 86.1579 Customer182: Waited  0.536
# 86.3194 Customer182: Finished
# 86.3194 Customer183: Waited  0.499
# 86.4417 Customer183: Finished
# 86.9672 Customer184: Arrival
# 86.9672 Customer184: Waited  0.000
# 87.0443 Customer184: Finished
# 87.4445 Customer185: Arrival
# 87.4445 Customer185: Waited  0.000
# 87.5346 Customer186: Arrival
# 87.9794 Customer187: Arrival
# 88.2250 Customer185: Finished
# 88.2250 Customer186: Waited  0.690
# 88.6895 Customer188: Arrival
# 88.8323 Customer186: Finished
# 88.8323 Customer187: Waited  0.853
# 88.8647 Customer187: Finished
# 88.8647 Customer188: Waited  0.175
# 89.0143 Customer188: Finished
# 89.1684 Customer189: Arrival
# 89.1684 Customer189: Waited  0.000
# 89.6041 Customer189: Finished
# 90.1454 Customer190: Arrival
# 90.1454 Customer190: Waited  0.000
# 90.2945 Customer190: Finished
# 90.8398 Customer191: Arrival
# 90.8398 Customer191: Waited  0.000
# 90.9888 Customer191: Finished
# 91.6423 Customer192: Arrival
# 91.6423 Customer192: Waited  0.000
# 91.8004 Customer193: Arrival
# 92.0066 Customer192: Finished
# 92.0066 Customer193: Waited  0.206
# 92.0461 Customer194: Arrival
# 92.1754 Customer195: Arrival
# 92.2327 Customer193: Finished
# 92.2327 Customer194: Waited  0.187
# 92.3207 Customer196: Arrival
# 92.4743 Customer194: Finished
# 92.4743 Customer195: Waited  0.299
# 92.5044 Customer197: Arrival
# 93.1526 Customer198: Arrival
# 93.2989 Customer195: Finished
# 93.2989 Customer196: Waited  0.978
# 93.3940 Customer199: Arrival
# 93.7701 Customer196: Finished
# 93.7701 Customer197: Waited  1.266
# 93.8824 Customer197: Finished
# 93.8824 Customer198: Waited  0.730
# 93.8842 Customer198: Finished
# 93.8842 Customer199: Waited  0.490
# 93.9039 Customer199: Finished
# 95.1081 Customer200: Arrival
# 95.1081 Customer200: Waited  0.000
# 95.2591 Customer200: Finished
# 95.6552 Customer201: Arrival
# 95.6552 Customer201: Waited  0.000
# 95.6624 Customer202: Arrival
# 96.2073 Customer203: Arrival
# 97.2120 Customer204: Arrival
# 97.7569 Customer201: Finished
# 97.7569 Customer202: Waited  2.094
# 98.0106 Customer202: Finished
# 98.0106 Customer203: Waited  1.803
# 98.9466 Customer203: Finished
# 98.9466 Customer204: Waited  1.735
# 99.0955 Customer204: Finished
# 99.2172 Customer205: Arrival
# 99.2172 Customer205: Waited  0.000
# 99.2488 Customer206: Arrival
# 99.4273 Customer205: Finished
# 99.4273 Customer206: Waited  0.179
# 99.4909 Customer206: Finished
# 101.0380 Customer207: Arrival
# 101.0380 Customer207: Waited  0.000
# 101.0625 Customer207: Finished
# 101.2541 Customer208: Arrival
# 101.2541 Customer208: Waited  0.000
# 101.2553 Customer208: Finished
# 103.1897 Customer209: Arrival
# 103.1897 Customer209: Waited  0.000
# 103.6644 Customer209: Finished
# 103.7527 Customer210: Arrival
# 103.7527 Customer210: Waited  0.000
# 103.9326 Customer210: Finished
# 104.8983 Customer211: Arrival
# 104.8983 Customer211: Waited  0.000
# 104.9834 Customer211: Finished
# 105.3004 Customer212: Arrival
# 105.3004 Customer212: Waited  0.000
# 105.6551 Customer213: Arrival
# 105.8180 Customer212: Finished
# 105.8180 Customer213: Waited  0.163
# 105.9459 Customer213: Finished
# 105.9557 Customer214: Arrival
# 105.9557 Customer214: Waited  0.000
# 106.0031 Customer215: Arrival
# 106.0446 Customer214: Finished
# 106.0446 Customer215: Waited  0.042
# 106.3787 Customer215: Finished
# 106.6753 Customer216: Arrival
# 106.6753 Customer216: Waited  0.000
# 106.7573 Customer216: Finished
# 106.8451 Customer217: Arrival
# 106.8451 Customer217: Waited  0.000
# 107.1056 Customer217: Finished
# 108.0286 Customer218: Arrival
# 108.0286 Customer218: Waited  0.000
# 108.3007 Customer219: Arrival
# 108.7450 Customer220: Arrival
# 108.7573 Customer218: Finished
# 108.7573 Customer219: Waited  0.457
# 109.0773 Customer219: Finished
# 109.0773 Customer220: Waited  0.332
# 109.5811 Customer220: Finished
# 109.9404 Customer221: Arrival
# 109.9404 Customer221: Waited  0.000
# 109.9419 Customer222: Arrival
# 110.4615 Customer223: Arrival
# 110.4842 Customer221: Finished
# 110.4842 Customer222: Waited  0.542
# 110.7477 Customer222: Finished
# 110.7477 Customer223: Waited  0.286
# 111.2189 Customer223: Finished
# 111.2459 Customer224: Arrival
# 111.2459 Customer224: Waited  0.000
# 111.2738 Customer225: Arrival
# 111.3132 Customer224: Finished
# 111.3132 Customer225: Waited  0.039
# 111.6797 Customer225: Finished
# 111.9968 Customer226: Arrival
# 111.9968 Customer226: Waited  0.000
# 112.1398 Customer226: Finished
# 112.1683 Customer227: Arrival
# 112.1683 Customer227: Waited  0.000
# 112.2950 Customer227: Finished
# 112.6246 Customer228: Arrival
# 112.6246 Customer228: Waited  0.000
# 112.6393 Customer229: Arrival
# 112.8242 Customer228: Finished
# 112.8242 Customer229: Waited  0.185
# 112.9023 Customer230: Arrival
# 113.0772 Customer229: Finished
# 113.0772 Customer230: Waited  0.175
# 113.3091 Customer231: Arrival
# 113.3800 Customer230: Finished
# 113.3800 Customer231: Waited  0.071
# 113.4545 Customer231: Finished
# 113.5866 Customer232: Arrival
# 113.5866 Customer232: Waited  0.000
# 113.6752 Customer233: Arrival
# 113.6886 Customer232: Finished
# 113.6886 Customer233: Waited  0.013
# 113.7437 Customer233: Finished
# 114.1773 Customer234: Arrival
# 114.1773 Customer234: Waited  0.000
# 114.2898 Customer234: Finished
# 114.6643 Customer235: Arrival
# 114.6643 Customer235: Waited  0.000
# 114.9287 Customer235: Finished
# 116.1769 Customer236: Arrival
# 116.1769 Customer236: Waited  0.000
# 116.2421 Customer236: Finished
# 116.2945 Customer237: Arrival
# 116.2945 Customer237: Waited  0.000
# 116.3398 Customer238: Arrival
# 116.6012 Customer237: Finished
# 116.6012 Customer238: Waited  0.261
# 116.6235 Customer239: Arrival
# 116.6469 Customer240: Arrival
# 116.8986 Customer238: Finished
# 116.8986 Customer239: Waited  0.275
# 116.9292 Customer239: Finished
# 116.9292 Customer240: Waited  0.282
# 117.0671 Customer241: Arrival
# 117.1496 Customer240: Finished
# 117.1496 Customer241: Waited  0.082
# 117.3217 Customer241: Finished
# 119.6458 Customer242: Arrival
# 119.6458 Customer242: Waited  0.000
# 119.8305 Customer242: Finished
# 120.9827 Customer243: Arrival
# 120.9827 Customer243: Waited  0.000
# 121.0245 Customer244: Arrival
# 121.1637 Customer245: Arrival
# 121.2913 Customer246: Arrival
# 121.3315 Customer247: Arrival
# 121.4966 Customer243: Finished
# 121.4966 Customer244: Waited  0.472
# 121.5145 Customer244: Finished
# 121.5145 Customer245: Waited  0.351
# 121.6535 Customer248: Arrival
# 121.8250 Customer245: Finished
# 121.8250 Customer246: Waited  0.534
# 121.8541 Customer249: Arrival
# 122.0557 Customer250: Arrival
# 122.1020 Customer246: Finished
# 122.1020 Customer247: Waited  0.771
# 122.2010 Customer247: Finished
# 122.2010 Customer248: Waited  0.548
# 122.2081 Customer251: Arrival
# 122.3754 Customer248: Finished
# 122.3754 Customer249: Waited  0.521
# 122.6974 Customer249: Finished
# 122.6974 Customer250: Waited  0.642
# 122.9900 Customer250: Finished
# 122.9900 Customer251: Waited  0.782
# 123.0415 Customer252: Arrival
# 123.1291 Customer251: Finished
# 123.1291 Customer252: Waited  0.088
# 123.1370 Customer252: Finished
# 123.9522 Customer253: Arrival
# 123.9522 Customer253: Waited  0.000
# 124.1273 Customer253: Finished
# 124.2924 Customer254: Arrival
# 124.2924 Customer254: Waited  0.000
# 124.3016 Customer254: Finished
# 124.9601 Customer255: Arrival
# 124.9601 Customer255: Waited  0.000
# 125.2579 Customer255: Finished
# 125.6704 Customer256: Arrival
# 125.6704 Customer256: Waited  0.000
# 125.9578 Customer256: Finished
# 126.0396 Customer257: Arrival
# 126.0396 Customer257: Waited  0.000
# 126.0751 Customer257: Finished
# 127.2006 Customer258: Arrival
# 127.2006 Customer258: Waited  0.000
# 127.2138 Customer259: Arrival
# 127.3855 Customer258: Finished
# 127.3855 Customer259: Waited  0.172
# 127.6982 Customer259: Finished
# 128.5314 Customer260: Arrival
# 128.5314 Customer260: Waited  0.000
# 128.7742 Customer260: Finished
# 128.8726 Customer261: Arrival
# 128.8726 Customer261: Waited  0.000
# 129.3725 Customer262: Arrival
# 129.4449 Customer263: Arrival
# 129.4945 Customer264: Arrival
# 129.9054 Customer265: Arrival
# 130.3988 Customer261: Finished
# 130.3988 Customer262: Waited  1.026
# 131.0456 Customer266: Arrival
# 131.5813 Customer267: Arrival
# 131.5879 Customer262: Finished
# 131.5879 Customer263: Waited  2.143
# 132.0121 Customer263: Finished
# 132.0121 Customer264: Waited  2.518
# 132.0180 Customer264: Finished
# 132.0180 Customer265: Waited  2.113
# 132.0348 Customer268: Arrival
# 132.0991 Customer269: Arrival
# 132.1151 Customer265: Finished
# 132.1151 Customer266: Waited  1.070
# 132.4646 Customer266: Finished
# 132.4646 Customer267: Waited  0.883
# 132.5357 Customer270: Arrival
# 132.6115 Customer271: Arrival
# 132.6814 Customer272: Arrival
# 133.0069 Customer273: Arrival
# 133.0134 Customer267: Finished
# 133.0134 Customer268: Waited  0.979
# 133.6020 Customer274: Arrival
# 134.0013 Customer268: Finished
# 134.0013 Customer269: Waited  1.902
# 134.0395 Customer275: Arrival
# 134.1035 Customer276: Arrival
# 134.1117 Customer269: Finished
# 134.1117 Customer270: Waited  1.576
# 134.2710 Customer270: Finished
# 134.2710 Customer271: Waited  1.659
# 134.6289 Customer271: Finished
# 134.6289 Customer272: Waited  1.947
# 134.8463 Customer277: Arrival
# 135.1285 Customer272: Finished
# 135.1285 Customer273: Waited  2.122
# 135.2453 Customer273: Finished
# 135.2453 Customer274: Waited  1.643
# 135.3264 Customer274: Finished
# 135.3264 Customer275: Waited  1.287
# 135.5298 Customer278: Arrival
# 135.5601 Customer279: Arrival
# 135.8175 Customer280: Arrival
# 135.8456 Customer275: Finished
# 135.8456 Customer276: Waited  1.742
# 136.0331 Customer276: Finished
# 136.0331 Customer277: Waited  1.187
# 136.0878 Customer277: Finished
# 136.0878 Customer278: Waited  0.558
# 136.2250 Customer281: Arrival
# 136.5179 Customer278: Finished
# 136.5179 Customer279: Waited  0.958
# 136.6393 Customer279: Finished
# 136.6393 Customer280: Waited  0.822
# 136.7627 Customer282: Arrival
# 136.7662 Customer280: Finished
# 136.7662 Customer281: Waited  0.541
# 136.7921 Customer281: Finished
# 136.7921 Customer282: Waited  0.029
# 136.8505 Customer283: Arrival
# 137.1883 Customer284: Arrival
# 137.2979 Customer285: Arrival
# 137.3169 Customer282: Finished
# 137.3169 Customer283: Waited  0.466
# 137.4914 Customer283: Finished
# 137.4914 Customer284: Waited  0.303
# 137.5971 Customer284: Finished
# 137.5971 Customer285: Waited  0.299
# 137.7465 Customer285: Finished
# 138.4673 Customer286: Arrival
# 138.4673 Customer286: Waited  0.000
# 138.7669 Customer286: Finished
# 139.7272 Customer287: Arrival
# 139.7272 Customer287: Waited  0.000
# 139.9138 Customer287: Finished
# 140.0690 Customer288: Arrival
# 140.0690 Customer288: Waited  0.000
# 140.1311 Customer288: Finished
# 140.5063 Customer289: Arrival
# 140.5063 Customer289: Waited  0.000
# 140.8637 Customer290: Arrival
# 140.9938 Customer289: Finished
# 140.9938 Customer290: Waited  0.130
# 141.2292 Customer290: Finished
# 141.3632 Customer291: Arrival
# 141.3632 Customer291: Waited  0.000
# 141.3995 Customer291: Finished
# 141.4702 Customer292: Arrival
# 141.4702 Customer292: Waited  0.000
# 141.4832 Customer292: Finished
# 141.4869 Customer293: Arrival
# 141.4869 Customer293: Waited  0.000
# 141.6105 Customer293: Finished
# 141.6748 Customer294: Arrival
# 141.6748 Customer294: Waited  0.000
# 142.1120 Customer295: Arrival
# 142.2725 Customer294: Finished
# 142.2725 Customer295: Waited  0.160
# 142.4018 Customer296: Arrival
# 142.5757 Customer297: Arrival
# 142.5990 Customer295: Finished
# 142.5990 Customer296: Waited  0.197
# 142.6733 Customer296: Finished
# 142.6733 Customer297: Waited  0.098
# 142.7695 Customer297: Finished
# 143.2477 Customer298: Arrival
# 143.2477 Customer298: Waited  0.000
# 143.3390 Customer299: Arrival
# 143.4785 Customer300: Arrival
# 143.5985 Customer298: Finished
# 143.5985 Customer299: Waited  0.259
# 143.7578 Customer299: Finished
# 143.7578 Customer300: Waited  0.279
# 143.8950 Customer300: Finished
# 143.9565 Customer301: Arrival
# 143.9565 Customer301: Waited  0.000
# 144.1132 Customer301: Finished
# 144.1861 Customer302: Arrival
# 144.1861 Customer302: Waited  0.000
# 144.6640 Customer303: Arrival
# 144.6966 Customer302: Finished
# 144.6966 Customer303: Waited  0.033
# 144.7615 Customer303: Finished
# 145.1371 Customer304: Arrival
# 145.1371 Customer304: Waited  0.000
# 145.5112 Customer304: Finished
# 145.8218 Customer305: Arrival
# 145.8218 Customer305: Waited  0.000
# 145.9563 Customer306: Arrival
# 145.9978 Customer307: Arrival
# 146.0717 Customer305: Finished
# 146.0717 Customer306: Waited  0.115
# 146.0955 Customer308: Arrival
# 146.4800 Customer306: Finished
# 146.4800 Customer307: Waited  0.482
# 146.6617 Customer309: Arrival
# 146.7592 Customer307: Finished
# 146.7592 Customer308: Waited  0.664
# 146.8079 Customer308: Finished
# 146.8079 Customer309: Waited  0.146
# 146.8348 Customer310: Arrival
# 147.3982 Customer309: Finished
# 147.3982 Customer310: Waited  0.563
# 147.4488 Customer311: Arrival
# 147.5683 Customer312: Arrival
# 147.9107 Customer310: Finished
# 147.9107 Customer311: Waited  0.462
# 148.0707 Customer311: Finished
# 148.0707 Customer312: Waited  0.502
# 148.1050 Customer313: Arrival
# 148.1940 Customer314: Arrival
# 148.5079 Customer312: Finished
# 148.5079 Customer313: Waited  0.403
# 149.0357 Customer313: Finished
# 149.0357 Customer314: Waited  0.842
# 149.2523 Customer314: Finished
# 149.4944 Customer315: Arrival
# 149.4944 Customer315: Waited  0.000
# 150.0242 Customer316: Arrival
# 150.1022 Customer315: Finished
# 150.1022 Customer316: Waited  0.078
# 150.4623 Customer316: Finished
# 150.7833 Customer317: Arrival
# 150.7833 Customer317: Waited  0.000
# 150.8260 Customer318: Arrival
# 151.3180 Customer317: Finished
# 151.3180 Customer318: Waited  0.492
# 151.7335 Customer319: Arrival
# 152.0455 Customer318: Finished
# 152.0455 Customer319: Waited  0.312
# 152.0888 Customer319: Finished
# 152.2354 Customer320: Arrival
# 152.2354 Customer320: Waited  0.000
# 152.3514 Customer320: Finished
# 152.8485 Customer321: Arrival
# 152.8485 Customer321: Waited  0.000
# 153.8710 Customer321: Finished
# 155.7725 Customer322: Arrival
# 155.7725 Customer322: Waited  0.000
# 156.0380 Customer322: Finished
# 156.7120 Customer323: Arrival
# 156.7120 Customer323: Waited  0.000
# 156.7903 Customer324: Arrival
# 156.9688 Customer325: Arrival
# 157.0774 Customer326: Arrival
# 157.0978 Customer327: Arrival
# 157.2305 Customer328: Arrival
# 157.2728 Customer329: Arrival
# 157.3430 Customer323: Finished
# 157.3430 Customer324: Waited  0.553
# 157.6154 Customer330: Arrival
# 157.6321 Customer324: Finished
# 157.6321 Customer325: Waited  0.663
# 157.8526 Customer325: Finished
# 157.8526 Customer326: Waited  0.775
# 158.1239 Customer331: Arrival
# 158.1247 Customer326: Finished
# 158.1247 Customer327: Waited  1.027
# 158.5678 Customer327: Finished
# 158.5678 Customer328: Waited  1.337
# 158.9077 Customer328: Finished
# 158.9077 Customer329: Waited  1.635
# 159.3720 Customer329: Finished
# 159.3720 Customer330: Waited  1.757
# 159.4157 Customer330: Finished
# 159.4157 Customer331: Waited  1.292
# 159.4335 Customer331: Finished
# 159.5802 Customer332: Arrival
# 159.5802 Customer332: Waited  0.000
# 159.7795 Customer332: Finished
# 160.1785 Customer333: Arrival
# 160.1785 Customer333: Waited  0.000
# 160.2805 Customer333: Finished
# 161.4591 Customer334: Arrival
# 161.4591 Customer334: Waited  0.000
# 161.9006 Customer334: Finished
# 162.1128 Customer335: Arrival
# 162.1128 Customer335: Waited  0.000
# 162.3964 Customer336: Arrival
# 162.4214 Customer335: Finished
# 162.4214 Customer336: Waited  0.025
# 162.4600 Customer337: Arrival
# 162.5351 Customer338: Arrival
# 162.8330 Customer336: Finished
# 162.8330 Customer337: Waited  0.373
# 162.8892 Customer339: Arrival
# 163.0488 Customer337: Finished
# 163.0488 Customer338: Waited  0.514
# 163.2773 Customer340: Arrival
# 163.5213 Customer338: Finished
# 163.5213 Customer339: Waited  0.632
# 163.8009 Customer341: Arrival
# 163.9446 Customer342: Arrival
# 163.9631 Customer339: Finished
# 163.9631 Customer340: Waited  0.686
# 164.0553 Customer343: Arrival
# 164.0596 Customer344: Arrival
# 164.1746 Customer340: Finished
# 164.1746 Customer341: Waited  0.374
# 164.2696 Customer345: Arrival
# 164.8057 Customer346: Arrival
# 165.1164 Customer341: Finished
# 165.1164 Customer342: Waited  1.172
# 165.4010 Customer342: Finished
# 165.4010 Customer343: Waited  1.346
# 165.7327 Customer347: Arrival
# 165.7567 Customer343: Finished
# 165.7567 Customer344: Waited  1.697
# 165.8365 Customer348: Arrival
# 166.4543 Customer344: Finished
# 166.4543 Customer345: Waited  2.185
# 166.5893 Customer345: Finished
# 166.5893 Customer346: Waited  1.784
# 167.0727 Customer346: Finished
# 167.0727 Customer347: Waited  1.340
# 167.2030 Customer347: Finished
# 167.2030 Customer348: Waited  1.366
# 167.2315 Customer348: Finished
# 167.7838 Customer349: Arrival
# 167.7838 Customer349: Waited  0.000
# 168.0223 Customer350: Arrival
# 168.3285 Customer351: Arrival
# 168.4880 Customer349: Finished
# 168.4880 Customer350: Waited  0.466
# 168.5402 Customer350: Finished
# 168.5402 Customer351: Waited  0.212
# 168.7817 Customer351: Finished
# 169.0024 Customer352: Arrival
# 169.0024 Customer352: Waited  0.000
# 169.0114 Customer352: Finished
# 170.1325 Customer353: Arrival
# 170.1325 Customer353: Waited  0.000
# 170.1428 Customer353: Finished
# 170.8820 Customer354: Arrival
# 170.8820 Customer354: Waited  0.000
# 170.9172 Customer354: Finished
# 171.0894 Customer355: Arrival
# 171.0894 Customer355: Waited  0.000
# 171.1515 Customer356: Arrival
# 171.3359 Customer355: Finished
# 171.3359 Customer356: Waited  0.184
# 171.4763 Customer357: Arrival
# 171.5997 Customer356: Finished
# 171.5997 Customer357: Waited  0.123
# 171.7424 Customer358: Arrival
# 172.8018 Customer359: Arrival
# 173.0847 Customer360: Arrival
# 173.3933 Customer361: Arrival
# 173.5116 Customer357: Finished
# 173.5116 Customer358: Waited  1.769
# 173.7731 Customer358: Finished
# 173.7731 Customer359: Waited  0.971
# 173.7784 Customer359: Finished
# 173.7784 Customer360: Waited  0.694
# 173.7893 Customer360: Finished
# 173.7893 Customer361: Waited  0.396
# 174.0223 Customer362: Arrival
# 174.2350 Customer361: Finished
# 174.2350 Customer362: Waited  0.213
# 174.3304 Customer362: Finished
# 174.5832 Customer363: Arrival
# 174.5832 Customer363: Waited  0.000
# 174.6242 Customer364: Arrival
# 174.7522 Customer363: Finished
# 174.7522 Customer364: Waited  0.128
# 174.7597 Customer364: Finished
# 174.8385 Customer365: Arrival
# 174.8385 Customer365: Waited  0.000
# 174.9409 Customer365: Finished
# 175.4809 Customer366: Arrival
# 175.4809 Customer366: Waited  0.000
# 175.5489 Customer367: Arrival
# 176.3009 Customer368: Arrival
# 176.3490 Customer366: Finished
# 176.3490 Customer367: Waited  0.800
# 176.4212 Customer367: Finished
# 176.4212 Customer368: Waited  0.120
# 176.5628 Customer369: Arrival
# 176.6997 Customer370: Arrival
# 176.9198 Customer368: Finished
# 176.9198 Customer369: Waited  0.357
# 176.9722 Customer369: Finished
# 176.9722 Customer370: Waited  0.272
# 177.0854 Customer371: Arrival
# 177.5028 Customer370: Finished
# 177.5028 Customer371: Waited  0.417
# 177.5276 Customer372: Arrival
# 177.6840 Customer371: Finished
# 177.6840 Customer372: Waited  0.156
# 177.7829 Customer373: Arrival
# 177.9345 Customer372: Finished
# 177.9345 Customer373: Waited  0.152
# 178.3179 Customer373: Finished
# 178.6261 Customer374: Arrival
# 178.6261 Customer374: Waited  0.000
# 178.6296 Customer374: Finished
# 178.9171 Customer375: Arrival
# 178.9171 Customer375: Waited  0.000
# 178.9949 Customer375: Finished
# 179.8095 Customer376: Arrival
# 179.8095 Customer376: Waited  0.000
# 179.9215 Customer376: Finished
# 180.7334 Customer377: Arrival
# 180.7334 Customer377: Waited  0.000
# 180.7988 Customer377: Finished
# 181.3174 Customer378: Arrival
# 181.3174 Customer378: Waited  0.000
# 181.6548 Customer379: Arrival
# 181.9085 Customer378: Finished
# 181.9085 Customer379: Waited  0.254
# 182.0258 Customer379: Finished
# 182.1381 Customer380: Arrival
# 182.1381 Customer380: Waited  0.000
# 182.1488 Customer380: Finished
# 182.1663 Customer381: Arrival
# 182.1663 Customer381: Waited  0.000
# 182.5987 Customer381: Finished
# 182.6708 Customer382: Arrival
# 182.6708 Customer382: Waited  0.000
# 182.7220 Customer383: Arrival
# 182.9027 Customer384: Arrival
# 182.9935 Customer382: Finished
# 182.9935 Customer383: Waited  0.272
# 183.1119 Customer385: Arrival
# 183.1379 Customer383: Finished
# 183.1379 Customer384: Waited  0.235
# 183.7438 Customer384: Finished
# 183.7438 Customer385: Waited  0.632
# 183.8966 Customer385: Finished
# 184.5897 Customer386: Arrival
# 184.5897 Customer386: Waited  0.000
# 184.6649 Customer386: Finished
# 184.8307 Customer387: Arrival
# 184.8307 Customer387: Waited  0.000
# 185.2351 Customer387: Finished
# 185.4084 Customer388: Arrival
# 185.4084 Customer388: Waited  0.000
# 185.4736 Customer389: Arrival
# 185.6595 Customer388: Finished
# 185.6595 Customer389: Waited  0.186
# 185.8050 Customer389: Finished
# 186.1467 Customer390: Arrival
# 186.1467 Customer390: Waited  0.000
# 186.4301 Customer391: Arrival
# 186.7391 Customer390: Finished
# 186.7391 Customer391: Waited  0.309
# 186.9179 Customer391: Finished
# 187.3671 Customer392: Arrival
# 187.3671 Customer392: Waited  0.000
# 187.3681 Customer392: Finished
# 187.5085 Customer393: Arrival
# 187.5085 Customer393: Waited  0.000
# 187.7411 Customer393: Finished
# 190.4141 Customer394: Arrival
# 190.4141 Customer394: Waited  0.000
# 190.5516 Customer394: Finished
# 190.6920 Customer395: Arrival
# 190.6920 Customer395: Waited  0.000
# 190.8675 Customer396: Arrival
# 191.1963 Customer395: Finished
# 191.1963 Customer396: Waited  0.329
# 191.3460 Customer397: Arrival
# 191.6686 Customer398: Arrival
# 191.7108 Customer399: Arrival
# 191.7895 Customer400: Arrival
# 192.8265 Customer396: Finished
# 192.8265 Customer397: Waited  1.480
# 192.8443 Customer401: Arrival
# 193.0515 Customer397: Finished
# 193.0515 Customer398: Waited  1.383
# 193.5338 Customer402: Arrival
# 193.6125 Customer403: Arrival
# 193.6899 Customer404: Arrival
# 194.2259 Customer398: Finished
# 194.2259 Customer399: Waited  2.515
# 194.2303 Customer399: Finished
# 194.2303 Customer400: Waited  2.441
# 194.3985 Customer400: Finished
# 194.3985 Customer401: Waited  1.554
# 194.4288 Customer405: Arrival
# 194.6655 Customer406: Arrival
# 194.8369 Customer401: Finished
# 194.8369 Customer402: Waited  1.303
# 194.8514 Customer407: Arrival
# 195.0213 Customer402: Finished
# 195.0213 Customer403: Waited  1.409
# 195.0742 Customer403: Finished
# 195.0742 Customer404: Waited  1.384
# 195.3327 Customer404: Finished
# 195.3327 Customer405: Waited  0.904
# 195.3610 Customer405: Finished
# 195.3610 Customer406: Waited  0.695
# 195.5208 Customer406: Finished
# 195.5208 Customer407: Waited  0.669
# 195.6087 Customer408: Arrival
# 196.0102 Customer407: Finished
# 196.0102 Customer408: Waited  0.401
# 196.2307 Customer408: Finished
# 196.2470 Customer409: Arrival
# 196.2470 Customer409: Waited  0.000
# 196.4631 Customer409: Finished
# 196.6092 Customer410: Arrival
# 196.6092 Customer410: Waited  0.000
# 196.8846 Customer410: Finished
# 197.2851 Customer411: Arrival
# 197.2851 Customer411: Waited  0.000
# 197.3235 Customer412: Arrival
# 197.3436 Customer411: Finished
# 197.3436 Customer412: Waited  0.020
# 197.3512 Customer412: Finished
# 198.7963 Customer413: Arrival
# 198.7963 Customer413: Waited  0.000
# 199.2685 Customer414: Arrival
# 199.3879 Customer413: Finished
# 199.3879 Customer414: Waited  0.119
# 199.4961 Customer414: Finished
# 199.9539 Customer415: Arrival
# 199.9539 Customer415: Waited  0.000
# 200.5329 Customer416: Arrival
# 200.6229 Customer415: Finished
# 200.6229 Customer416: Waited  0.090
# 200.7134 Customer416: Finished
# 201.5277 Customer417: Arrival
# 201.5277 Customer417: Waited  0.000
# 201.6108 Customer417: Finished
# 201.8554 Customer418: Arrival
# 201.8554 Customer418: Waited  0.000
# 201.8967 Customer419: Arrival
# 201.9488 Customer420: Arrival
# 202.1893 Customer418: Finished
# 202.1893 Customer419: Waited  0.293
# 202.3444 Customer421: Arrival
# 202.3891 Customer419: Finished
# 202.3891 Customer420: Waited  0.440
# 202.5185 Customer422: Arrival
# 202.6655 Customer420: Finished
# 202.6655 Customer421: Waited  0.321
# 202.7252 Customer421: Finished
# 202.7252 Customer422: Waited  0.207
# 203.3074 Customer422: Finished
# 204.6872 Customer423: Arrival
# 204.6872 Customer423: Waited  0.000
# 204.7294 Customer423: Finished
# 205.8229 Customer424: Arrival
# 205.8229 Customer424: Waited  0.000
# 205.9432 Customer425: Arrival
# 206.0666 Customer424: Finished
# 206.0666 Customer425: Waited  0.123
# 206.4318 Customer425: Finished
# 206.5749 Customer426: Arrival
# 206.5749 Customer426: Waited  0.000
# 206.9216 Customer426: Finished
# 207.6002 Customer427: Arrival
# 207.6002 Customer427: Waited  0.000
# 207.6299 Customer427: Finished
# 207.7103 Customer428: Arrival
# 207.7103 Customer428: Waited  0.000
# 207.8237 Customer429: Arrival
# 208.0278 Customer430: Arrival
# 208.0370 Customer428: Finished
# 208.0370 Customer429: Waited  0.213
# 208.1669 Customer429: Finished
# 208.1669 Customer430: Waited  0.139
# 208.2427 Customer431: Arrival
# 208.3878 Customer430: Finished
# 208.3878 Customer431: Waited  0.145
# 208.5287 Customer431: Finished
# 208.7448 Customer432: Arrival
# 208.7448 Customer432: Waited  0.000
# 209.1833 Customer433: Arrival
# 209.2168 Customer434: Arrival
# 209.5142 Customer435: Arrival
# 209.9783 Customer432: Finished
# 209.9783 Customer433: Waited  0.795
# 209.9918 Customer436: Arrival
# 210.3044 Customer433: Finished
# 210.3044 Customer434: Waited  1.088
# 210.3746 Customer437: Arrival
# 210.4050 Customer438: Arrival
# 210.7523 Customer439: Arrival
# 211.1631 Customer434: Finished
# 211.1631 Customer435: Waited  1.649
# 211.3733 Customer440: Arrival
# 211.8649 Customer435: Finished
# 211.8649 Customer436: Waited  1.873
# 212.0473 Customer436: Finished
# 212.0473 Customer437: Waited  1.673
# 212.1914 Customer441: Arrival
# 212.9666 Customer437: Finished
# 212.9666 Customer438: Waited  2.562
# 213.3609 Customer438: Finished
# 213.3609 Customer439: Waited  2.609
# 213.4506 Customer439: Finished
# 213.4506 Customer440: Waited  2.077
# 214.3135 Customer442: Arrival
# 214.3860 Customer440: Finished
# 214.3860 Customer441: Waited  2.195
# 214.4261 Customer441: Finished
# 214.4261 Customer442: Waited  0.113
# 214.6537 Customer442: Finished
# 215.4006 Customer443: Arrival
# 215.4006 Customer443: Waited  0.000
# 215.8223 Customer443: Finished
# 215.9608 Customer444: Arrival
# 215.9608 Customer444: Waited  0.000
# 216.0356 Customer445: Arrival
# 216.1007 Customer444: Finished
# 216.1007 Customer445: Waited  0.065
# 216.1833 Customer445: Finished
# 216.3441 Customer446: Arrival
# 216.3441 Customer446: Waited  0.000
# 216.3751 Customer446: Finished
# 218.4122 Customer447: Arrival
# 218.4122 Customer447: Waited  0.000
# 218.5289 Customer447: Finished
# 219.1092 Customer448: Arrival
# 219.1092 Customer448: Waited  0.000
# 219.3643 Customer448: Finished
# 219.9843 Customer449: Arrival
# 219.9843 Customer449: Waited  0.000
# 220.6770 Customer449: Finished
# 220.9314 Customer450: Arrival
# 220.9314 Customer450: Waited  0.000
# 221.0847 Customer451: Arrival
# 221.2556 Customer450: Finished
# 221.2556 Customer451: Waited  0.171
# 221.2805 Customer452: Arrival
# 221.3677 Customer451: Finished
# 221.3677 Customer452: Waited  0.087
# 221.3702 Customer452: Finished
# 221.8783 Customer453: Arrival
# 221.8783 Customer453: Waited  0.000
# 221.9374 Customer453: Finished
# 222.0798 Customer454: Arrival
# 222.0798 Customer454: Waited  0.000
# 222.1183 Customer454: Finished
# 222.2226 Customer455: Arrival
# 222.2226 Customer455: Waited  0.000
# 223.1386 Customer455: Finished
# 223.1844 Customer456: Arrival
# 223.1844 Customer456: Waited  0.000
# 223.7991 Customer457: Arrival
# 223.8044 Customer458: Arrival
# 224.8068 Customer459: Arrival
# 224.8898 Customer456: Finished
# 224.8898 Customer457: Waited  1.091
# 225.0265 Customer457: Finished
# 225.0265 Customer458: Waited  1.222
# 225.2143 Customer458: Finished
# 225.2143 Customer459: Waited  0.408
# 225.8747 Customer460: Arrival
# 226.1040 Customer461: Arrival
# 226.2908 Customer459: Finished
# 226.2908 Customer460: Waited  0.416
# 226.5045 Customer460: Finished
# 226.5045 Customer461: Waited  0.401
# 226.6354 Customer461: Finished
# 227.9421 Customer462: Arrival
# 227.9421 Customer462: Waited  0.000
# 227.9554 Customer462: Finished
# 228.1229 Customer463: Arrival
# 228.1229 Customer463: Waited  0.000
# 228.2437 Customer464: Arrival
# 228.6447 Customer465: Arrival
# 228.6620 Customer463: Finished
# 228.6620 Customer464: Waited  0.418
# 228.8594 Customer464: Finished
# 228.8594 Customer465: Waited  0.215
# 229.1561 Customer465: Finished
# 229.3196 Customer466: Arrival
# 229.3196 Customer466: Waited  0.000
# 229.3518 Customer467: Arrival
# 229.3683 Customer468: Arrival
# 229.4747 Customer466: Finished
# 229.4747 Customer467: Waited  0.123
# 229.5047 Customer469: Arrival
# 229.6565 Customer467: Finished
# 229.6565 Customer468: Waited  0.288
# 229.7240 Customer470: Arrival
# 229.9117 Customer468: Finished
# 229.9117 Customer469: Waited  0.407
# 230.0218 Customer469: Finished
# 230.0218 Customer470: Waited  0.298
# 230.0649 Customer470: Finished
# 231.3387 Customer471: Arrival
# 231.3387 Customer471: Waited  0.000
# 231.8882 Customer472: Arrival
# 232.0568 Customer471: Finished
# 232.0568 Customer472: Waited  0.169
# 232.2973 Customer473: Arrival
# 232.4627 Customer474: Arrival
# 232.6252 Customer472: Finished
# 232.6252 Customer473: Waited  0.328
# 232.7175 Customer475: Arrival
# 232.8648 Customer473: Finished
# 232.8648 Customer474: Waited  0.402
# 232.9020 Customer476: Arrival
# 232.9160 Customer474: Finished
# 232.9160 Customer475: Waited  0.199
# 232.9580 Customer475: Finished
# 232.9580 Customer476: Waited  0.056
# 233.4457 Customer476: Finished
# 234.5449 Customer477: Arrival
# 234.5449 Customer477: Waited  0.000
# 234.6327 Customer477: Finished
# 234.8531 Customer478: Arrival
# 234.8531 Customer478: Waited  0.000
# 235.0310 Customer478: Finished
# 235.1214 Customer479: Arrival
# 235.1214 Customer479: Waited  0.000
# 235.1451 Customer479: Finished
# 235.3723 Customer480: Arrival
# 235.3723 Customer480: Waited  0.000
# 235.3972 Customer480: Finished
# 235.5357 Customer481: Arrival
# 235.5357 Customer481: Waited  0.000
# 235.8937 Customer482: Arrival
# 236.1169 Customer481: Finished
# 236.1169 Customer482: Waited  0.223
# 236.2202 Customer482: Finished
# 236.3908 Customer483: Arrival
# 236.3908 Customer483: Waited  0.000
# 236.7317 Customer484: Arrival
# 236.8154 Customer483: Finished
# 236.8154 Customer484: Waited  0.084
# 236.8460 Customer485: Arrival
# 237.1014 Customer486: Arrival
# 237.1269 Customer484: Finished
# 237.1269 Customer485: Waited  0.281
# 237.8677 Customer485: Finished
# 237.8677 Customer486: Waited  0.766
# 238.6108 Customer486: Finished
# 238.8942 Customer487: Arrival
# 238.8942 Customer487: Waited  0.000
# 239.3251 Customer487: Finished
# 239.3990 Customer488: Arrival
# 239.3990 Customer488: Waited  0.000
# 239.4094 Customer488: Finished
# 240.6952 Customer489: Arrival
# 240.6952 Customer489: Waited  0.000
# 240.8326 Customer490: Arrival
# 242.1104 Customer491: Arrival
# 242.1354 Customer489: Finished
# 242.1354 Customer490: Waited  1.303
# 242.7199 Customer492: Arrival
# 242.7334 Customer493: Arrival
# 243.6646 Customer490: Finished
# 243.6646 Customer491: Waited  1.554
# 243.8614 Customer494: Arrival
# 244.0877 Customer495: Arrival
# 244.3441 Customer491: Finished
# 244.3441 Customer492: Waited  1.624
# 244.4516 Customer492: Finished
# 244.4516 Customer493: Waited  1.718
# 244.8256 Customer493: Finished
# 244.8256 Customer494: Waited  0.964
# 244.9538 Customer494: Finished
# 244.9538 Customer495: Waited  0.866
# 245.2185 Customer496: Arrival
# 245.2739 Customer497: Arrival
# 245.3409 Customer498: Arrival
# 245.5694 Customer495: Finished
# 245.5694 Customer496: Waited  0.351
# 246.1033 Customer499: Arrival
# 246.4111 Customer500: Arrival
# 246.5761 Customer496: Finished
# 246.5761 Customer497: Waited  1.302
# 246.6475 Customer501: Arrival
# ...
# 9930.6167 Customer19877: Waited  0.000
# 9930.6605 Customer19878: Arrival
# 9930.7416 Customer19879: Arrival
# 9930.7501 Customer19877: Finished
# 9930.7501 Customer19878: Waited  0.090
# 9930.9986 Customer19880: Arrival
# 9931.0624 Customer19878: Finished
# 9931.0624 Customer19879: Waited  0.321
# 9931.0965 Customer19879: Finished
# 9931.0965 Customer19880: Waited  0.098
# 9931.2799 Customer19880: Finished
# 9931.6248 Customer19881: Arrival
# 9931.6248 Customer19881: Waited  0.000
# 9931.7485 Customer19882: Arrival
# 9931.9749 Customer19881: Finished
# 9931.9749 Customer19882: Waited  0.226
# 9932.0337 Customer19882: Finished
# 9932.7303 Customer19883: Arrival
# 9932.7303 Customer19883: Waited  0.000
# 9933.1400 Customer19883: Finished
# 9933.7107 Customer19884: Arrival
# 9933.7107 Customer19884: Waited  0.000
# 9933.8297 Customer19885: Arrival
# 9934.7279 Customer19886: Arrival
# 9934.8900 Customer19887: Arrival
# 9935.0906 Customer19888: Arrival
# 9935.4824 Customer19884: Finished
# 9935.4824 Customer19885: Waited  1.653
# 9935.5502 Customer19885: Finished
# 9935.5502 Customer19886: Waited  0.822
# 9935.6048 Customer19889: Arrival
# 9935.6825 Customer19886: Finished
# 9935.6825 Customer19887: Waited  0.793
# 9936.1917 Customer19890: Arrival
# 9936.3378 Customer19891: Arrival
# 9936.3914 Customer19887: Finished
# 9936.3914 Customer19888: Waited  1.301
# 9937.3231 Customer19888: Finished
# 9937.3231 Customer19889: Waited  1.718
# 9937.4202 Customer19889: Finished
# 9937.4202 Customer19890: Waited  1.228
# 9937.7693 Customer19890: Finished
# 9937.7693 Customer19891: Waited  1.432
# 9937.8003 Customer19891: Finished
# 9938.1810 Customer19892: Arrival
# 9938.1810 Customer19892: Waited  0.000
# 9938.2466 Customer19893: Arrival
# 9938.2723 Customer19894: Arrival
# 9938.3899 Customer19892: Finished
# 9938.3899 Customer19893: Waited  0.143
# 9938.5057 Customer19893: Finished
# 9938.5057 Customer19894: Waited  0.233
# 9938.7384 Customer19894: Finished
# 9939.7002 Customer19895: Arrival
# 9939.7002 Customer19895: Waited  0.000
# 9940.1002 Customer19895: Finished
# 9940.2084 Customer19896: Arrival
# 9940.2084 Customer19896: Waited  0.000
# 9940.3671 Customer19897: Arrival
# 9940.5939 Customer19898: Arrival
# 9940.7441 Customer19899: Arrival
# 9940.8855 Customer19900: Arrival
# 9940.8894 Customer19896: Finished
# 9940.8894 Customer19897: Waited  0.522
# 9941.0659 Customer19901: Arrival
# 9941.2134 Customer19902: Arrival
# 9941.4401 Customer19897: Finished
# 9941.4401 Customer19898: Waited  0.846
# 9941.4705 Customer19903: Arrival
# 9941.6200 Customer19898: Finished
# 9941.6200 Customer19899: Waited  0.876
# 9941.7905 Customer19899: Finished
# 9941.7905 Customer19900: Waited  0.905
# 9941.7940 Customer19904: Arrival
# 9942.3685 Customer19905: Arrival
# 9942.4066 Customer19906: Arrival
# 9942.8418 Customer19900: Finished
# 9942.8418 Customer19901: Waited  1.776
# 9943.0891 Customer19901: Finished
# 9943.0891 Customer19902: Waited  1.876
# 9943.1025 Customer19902: Finished
# 9943.1025 Customer19903: Waited  1.632
# 9943.3060 Customer19903: Finished
# 9943.3060 Customer19904: Waited  1.512
# 9943.4191 Customer19907: Arrival
# 9943.5306 Customer19904: Finished
# 9943.5306 Customer19905: Waited  1.162
# 9943.5471 Customer19905: Finished
# 9943.5471 Customer19906: Waited  1.140
# 9943.7767 Customer19908: Arrival
# 9943.8421 Customer19906: Finished
# 9943.8421 Customer19907: Waited  0.423
# 9943.8858 Customer19907: Finished
# 9943.8858 Customer19908: Waited  0.109
# 9944.0777 Customer19908: Finished
# 9944.7964 Customer19909: Arrival
# 9944.7964 Customer19909: Waited  0.000
# 9944.8839 Customer19910: Arrival
# 9944.8889 Customer19909: Finished
# 9944.8889 Customer19910: Waited  0.005
# 9944.9717 Customer19910: Finished
# 9945.5939 Customer19911: Arrival
# 9945.5939 Customer19911: Waited  0.000
# 9945.7204 Customer19912: Arrival
# 9945.7520 Customer19913: Arrival
# 9946.0021 Customer19914: Arrival
# 9946.3005 Customer19911: Finished
# 9946.3005 Customer19912: Waited  0.580
# 9946.4479 Customer19915: Arrival
# 9946.4540 Customer19912: Finished
# 9946.4540 Customer19913: Waited  0.702
# 9946.8386 Customer19913: Finished
# 9946.8386 Customer19914: Waited  0.836
# 9946.8440 Customer19914: Finished
# 9946.8440 Customer19915: Waited  0.396
# 9947.0042 Customer19915: Finished
# 9947.3171 Customer19916: Arrival
# 9947.3171 Customer19916: Waited  0.000
# 9947.3947 Customer19916: Finished
# 9947.7829 Customer19917: Arrival
# 9947.7829 Customer19917: Waited  0.000
# 9948.0309 Customer19918: Arrival
# 9948.0354 Customer19917: Finished
# 9948.0354 Customer19918: Waited  0.005
# 9948.3332 Customer19919: Arrival
# 9948.3366 Customer19920: Arrival
# 9948.4268 Customer19921: Arrival
# 9948.5195 Customer19918: Finished
# 9948.5195 Customer19919: Waited  0.186
# 9948.6515 Customer19919: Finished
# 9948.6515 Customer19920: Waited  0.315
# 9949.4298 Customer19920: Finished
# 9949.4298 Customer19921: Waited  1.003
# 9949.5083 Customer19922: Arrival
# 9949.5583 Customer19921: Finished
# 9949.5583 Customer19922: Waited  0.050
# 9949.7238 Customer19922: Finished
# 9949.7517 Customer19923: Arrival
# 9949.7517 Customer19923: Waited  0.000
# 9949.8185 Customer19923: Finished
# 9949.8704 Customer19924: Arrival
# 9949.8704 Customer19924: Waited  0.000
# 9950.0299 Customer19924: Finished
# 9950.1454 Customer19925: Arrival
# 9950.1454 Customer19925: Waited  0.000
# 9950.5222 Customer19925: Finished
# 9950.5341 Customer19926: Arrival
# 9950.5341 Customer19926: Waited  0.000
# 9950.8533 Customer19927: Arrival
# 9950.8619 Customer19926: Finished
# 9950.8619 Customer19927: Waited  0.009
# 9951.0323 Customer19928: Arrival
# 9951.3096 Customer19927: Finished
# 9951.3096 Customer19928: Waited  0.277
# 9951.4069 Customer19928: Finished
# 9952.2171 Customer19929: Arrival
# 9952.2171 Customer19929: Waited  0.000
# 9952.4352 Customer19930: Arrival
# 9952.5676 Customer19931: Arrival
# 9952.7187 Customer19929: Finished
# 9952.7187 Customer19930: Waited  0.283
# 9952.8106 Customer19932: Arrival
# 9952.9819 Customer19930: Finished
# 9952.9819 Customer19931: Waited  0.414
# 9953.0224 Customer19933: Arrival
# 9953.1149 Customer19931: Finished
# 9953.1149 Customer19932: Waited  0.304
# 9953.1342 Customer19934: Arrival
# 9953.1575 Customer19935: Arrival
# 9953.2030 Customer19932: Finished
# 9953.2030 Customer19933: Waited  0.181
# 9953.4440 Customer19936: Arrival
# 9953.5983 Customer19933: Finished
# 9953.5983 Customer19934: Waited  0.464
# 9954.3846 Customer19937: Arrival
# 9954.6015 Customer19934: Finished
# 9954.6015 Customer19935: Waited  1.444
# 9954.9563 Customer19935: Finished
# 9954.9563 Customer19936: Waited  1.512
# 9954.9714 Customer19936: Finished
# 9954.9714 Customer19937: Waited  0.587
# 9955.4747 Customer19938: Arrival
# 9955.9314 Customer19937: Finished
# 9955.9314 Customer19938: Waited  0.457
# 9956.0723 Customer19938: Finished
# 9956.1896 Customer19939: Arrival
# 9956.1896 Customer19939: Waited  0.000
# 9956.9653 Customer19940: Arrival
# 9957.0550 Customer19941: Arrival
# 9957.3578 Customer19939: Finished
# 9957.3578 Customer19940: Waited  0.393
# 9957.3890 Customer19942: Arrival
# 9957.4906 Customer19940: Finished
# 9957.4906 Customer19941: Waited  0.436
# 9957.6081 Customer19943: Arrival
# 9957.7720 Customer19944: Arrival
# 9957.8266 Customer19941: Finished
# 9957.8266 Customer19942: Waited  0.438
# 9958.1541 Customer19942: Finished
# 9958.1541 Customer19943: Waited  0.546
# 9958.3479 Customer19943: Finished
# 9958.3479 Customer19944: Waited  0.576
# 9958.5552 Customer19944: Finished
# 9958.6508 Customer19945: Arrival
# 9958.6508 Customer19945: Waited  0.000
# 9960.3658 Customer19945: Finished
# 9963.3652 Customer19946: Arrival
# 9963.3652 Customer19946: Waited  0.000
# 9963.3898 Customer19947: Arrival
# 9963.4812 Customer19946: Finished
# 9963.4812 Customer19947: Waited  0.091
# 9963.4981 Customer19948: Arrival
# 9963.5596 Customer19949: Arrival
# 9964.0427 Customer19947: Finished
# 9964.0427 Customer19948: Waited  0.545
# 9964.1022 Customer19950: Arrival
# 9964.1856 Customer19951: Arrival
# 9964.2977 Customer19952: Arrival
# 9964.3570 Customer19953: Arrival
# 9964.6752 Customer19954: Arrival
# 9964.7209 Customer19955: Arrival
# 9964.8541 Customer19956: Arrival
# 9964.8983 Customer19948: Finished
# 9964.8983 Customer19949: Waited  1.339
# 9965.1317 Customer19949: Finished
# 9965.1317 Customer19950: Waited  1.030
# 9965.1449 Customer19957: Arrival
# 9965.1476 Customer19950: Finished
# 9965.1476 Customer19951: Waited  0.962
# 9965.2362 Customer19958: Arrival
# 9965.5378 Customer19951: Finished
# 9965.5378 Customer19952: Waited  1.240
# 9965.8131 Customer19959: Arrival
# 9966.2288 Customer19960: Arrival
# 9966.3016 Customer19952: Finished
# 9966.3016 Customer19953: Waited  1.945
# 9966.3731 Customer19953: Finished
# 9966.3731 Customer19954: Waited  1.698
# 9967.0055 Customer19954: Finished
# 9967.0055 Customer19955: Waited  2.285
# 9967.0158 Customer19961: Arrival
# 9967.1561 Customer19962: Arrival
# 9967.6499 Customer19963: Arrival
# 9967.6764 Customer19964: Arrival
# 9967.8156 Customer19965: Arrival
# 9967.9464 Customer19966: Arrival
# 9968.3921 Customer19955: Finished
# 9968.3921 Customer19956: Waited  3.538
# 9968.4098 Customer19956: Finished
# 9968.4098 Customer19957: Waited  3.265
# 9968.4789 Customer19967: Arrival
# 9968.7760 Customer19968: Arrival
# 9968.7879 Customer19957: Finished
# 9968.7879 Customer19958: Waited  3.552
# 9968.7936 Customer19958: Finished
# 9968.7936 Customer19959: Waited  2.980
# 9968.8368 Customer19969: Arrival
# 9968.8398 Customer19959: Finished
# 9968.8398 Customer19960: Waited  2.611
# 9968.9411 Customer19960: Finished
# 9968.9411 Customer19961: Waited  1.925
# 9968.9782 Customer19961: Finished
# 9968.9782 Customer19962: Waited  1.822
# 9969.1753 Customer19970: Arrival
# 9969.1824 Customer19962: Finished
# 9969.1824 Customer19963: Waited  1.533
# 9969.6237 Customer19971: Arrival
# 9969.6953 Customer19963: Finished
# 9969.6953 Customer19964: Waited  2.019
# 9969.7558 Customer19964: Finished
# 9969.7558 Customer19965: Waited  1.940
# 9969.8661 Customer19965: Finished
# 9969.8661 Customer19966: Waited  1.920
# 9970.0786 Customer19972: Arrival
# 9970.2954 Customer19966: Finished
# 9970.2954 Customer19967: Waited  1.816
# 9970.8906 Customer19973: Arrival
# 9971.2103 Customer19974: Arrival
# 9971.6431 Customer19967: Finished
# 9971.6431 Customer19968: Waited  2.867
# 9971.9326 Customer19975: Arrival
# 9972.2238 Customer19976: Arrival
# 9972.4550 Customer19977: Arrival
# 9972.5767 Customer19968: Finished
# 9972.5767 Customer19969: Waited  3.740
# 9972.6351 Customer19969: Finished
# 9972.6351 Customer19970: Waited  3.460
# 9972.7478 Customer19970: Finished
# 9972.7478 Customer19971: Waited  3.124
# 9972.8856 Customer19971: Finished
# 9972.8856 Customer19972: Waited  2.807
# 9973.0580 Customer19978: Arrival
# 9973.4627 Customer19972: Finished
# 9973.4627 Customer19973: Waited  2.572
# 9973.5295 Customer19979: Arrival
# 9973.5589 Customer19973: Finished
# 9973.5589 Customer19974: Waited  2.349
# 9973.9107 Customer19974: Finished
# 9973.9107 Customer19975: Waited  1.978
# 9973.9354 Customer19975: Finished
# 9973.9354 Customer19976: Waited  1.712
# 9974.2032 Customer19976: Finished
# 9974.2032 Customer19977: Waited  1.748
# 9974.2686 Customer19980: Arrival
# 9974.5481 Customer19981: Arrival
# 9974.6078 Customer19977: Finished
# 9974.6078 Customer19978: Waited  1.550
# 9974.6389 Customer19978: Finished
# 9974.6389 Customer19979: Waited  1.109
# 9974.9238 Customer19982: Arrival
# 9975.0026 Customer19979: Finished
# 9975.0026 Customer19980: Waited  0.734
# 9975.0098 Customer19983: Arrival
# 9975.0197 Customer19984: Arrival
# 9975.3546 Customer19985: Arrival
# 9975.5258 Customer19986: Arrival
# 9975.6191 Customer19980: Finished
# 9975.6191 Customer19981: Waited  1.071
# 9976.0111 Customer19981: Finished
# 9976.0111 Customer19982: Waited  1.087
# 9977.1159 Customer19982: Finished
# 9977.1159 Customer19983: Waited  2.106
# 9977.2359 Customer19983: Finished
# 9977.2359 Customer19984: Waited  2.216
# 9977.5268 Customer19987: Arrival
# 9977.6821 Customer19984: Finished
# 9977.6821 Customer19985: Waited  2.328
# 9977.7115 Customer19988: Arrival
# 9977.7591 Customer19989: Arrival
# 9978.0624 Customer19985: Finished
# 9978.0624 Customer19986: Waited  2.537
# 9978.0885 Customer19990: Arrival
# 9978.4814 Customer19986: Finished
# 9978.4814 Customer19987: Waited  0.955
# 9978.6008 Customer19987: Finished
# 9978.6008 Customer19988: Waited  0.889
# 9978.7175 Customer19988: Finished
# 9978.7175 Customer19989: Waited  0.958
# 9978.7434 Customer19989: Finished
# 9978.7434 Customer19990: Waited  0.655
# 9978.7944 Customer19990: Finished
# 9979.3991 Customer19991: Arrival
# 9979.3991 Customer19991: Waited  0.000
# 9979.5528 Customer19991: Finished
# 9979.9025 Customer19992: Arrival
# 9979.9025 Customer19992: Waited  0.000
# 9980.3966 Customer19992: Finished
# 9980.6146 Customer19993: Arrival
# 9980.6146 Customer19993: Waited  0.000
# 9980.7864 Customer19994: Arrival
# 9981.1440 Customer19993: Finished
# 9981.1440 Customer19994: Waited  0.358
# 9981.4446 Customer19994: Finished
# 9981.6342 Customer19995: Arrival
# 9981.6342 Customer19995: Waited  0.000
# 9981.6353 Customer19995: Finished
# 9981.9868 Customer19996: Arrival
# 9981.9868 Customer19996: Waited  0.000
# 9982.0585 Customer19996: Finished
# 9982.9207 Customer19997: Arrival
# 9982.9207 Customer19997: Waited  0.000
# 9983.2068 Customer19997: Finished
# 9983.8000 Customer19998: Arrival
# 9983.8000 Customer19998: Waited  0.000
# 9983.8199 Customer19998: Finished
# 9984.8185 Customer19999: Arrival
# 9984.8185 Customer19999: Waited  0.000
# 9984.8559 Customer20000: Arrival
# 9984.9048 Customer20001: Arrival
# 9984.9357 Customer19999: Finished
# 9984.9357 Customer20000: Waited  0.080
# 9985.6451 Customer20002: Arrival
# 9985.8585 Customer20000: Finished
# 9985.8585 Customer20001: Waited  0.954
# 9986.0525 Customer20001: Finished
# 9986.0525 Customer20002: Waited  0.407
# 9986.3395 Customer20002: Finished
# 9986.8006 Customer20003: Arrival
# 9986.8006 Customer20003: Waited  0.000
# 9986.8078 Customer20003: Finished
# 9987.4989 Customer20004: Arrival
# 9987.4989 Customer20004: Waited  0.000
# 9987.7111 Customer20005: Arrival
# 9988.0802 Customer20004: Finished
# 9988.0802 Customer20005: Waited  0.369
# 9989.5803 Customer20005: Finished
# 9989.8749 Customer20006: Arrival
# 9989.8749 Customer20006: Waited  0.000
# 9989.8819 Customer20006: Finished
# 9989.8902 Customer20007: Arrival
# 9989.8902 Customer20007: Waited  0.000
# 9989.9860 Customer20007: Finished
# 9990.0908 Customer20008: Arrival
# 9990.0908 Customer20008: Waited  0.000
# 9990.3997 Customer20008: Finished
# 9990.6230 Customer20009: Arrival
# 9990.6230 Customer20009: Waited  0.000
# 9990.9123 Customer20010: Arrival
# 9992.0254 Customer20009: Finished
# 9992.0254 Customer20010: Waited  1.113
# 9992.3466 Customer20010: Finished
# 9994.0014 Customer20011: Arrival
# 9994.0014 Customer20011: Waited  0.000
# 9994.1363 Customer20012: Arrival
# 9994.1721 Customer20013: Arrival
# 9994.2023 Customer20011: Finished
# 9994.2023 Customer20012: Waited  0.066
# 9994.2982 Customer20014: Arrival
# 9994.4681 Customer20012: Finished
# 9994.4681 Customer20013: Waited  0.296
# 9994.7578 Customer20013: Finished
# 9994.7578 Customer20014: Waited  0.460
# 9994.8787 Customer20014: Finished
# 9995.0697 Customer20015: Arrival
# 9995.0697 Customer20015: Waited  0.000
# 9995.2137 Customer20016: Arrival
# 9995.4270 Customer20015: Finished
# 9995.4270 Customer20016: Waited  0.213
# 9995.7519 Customer20016: Finished
# 9995.9042 Customer20017: Arrival
# 9995.9042 Customer20017: Waited  0.000
# 9995.9858 Customer20017: Finished
# 9996.2685 Customer20018: Arrival
# 9996.2685 Customer20018: Waited  0.000
# 9996.3862 Customer20019: Arrival
# 9996.6815 Customer20018: Finished
# 9996.6815 Customer20019: Waited  0.295
# 9997.0744 Customer20019: Finished
# 9997.8485 Customer20020: Arrival
# 9997.8485 Customer20020: Waited  0.000
# 9998.0154 Customer20020: Finished
# 9998.2368 Customer20021: Arrival
# 9998.2368 Customer20021: Waited  0.000
# 9998.3001 Customer20021: Finished
# 9998.3908 Customer20022: Arrival
# 9998.3908 Customer20022: Waited  0.000
# 9998.6703 Customer20022: Finished
# 9998.8582 Customer20023: Arrival
# 9998.8582 Customer20023: Waited  0.000
# 9998.9759 Customer20024: Arrival
# 9998.9999 Customer20025: Arrival
# 9999.6094 Customer20023: Finished
# 9999.6094 Customer20024: Waited  0.634
# 9999.9241 Customer20026: Arrival
# 9999.9286 Customer20024: Finished
# 9999.9286 Customer20025: Waited  0.929
# Utilization: 0.670925923194053
# Average waiting time: 0.7079642806936252
