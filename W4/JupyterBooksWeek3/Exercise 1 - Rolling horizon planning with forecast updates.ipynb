# %%
import numpy as np
import gurobipy as gp
from gurobipy import GRB

# define parameters
periods = 12

demand = [66, 78, 57, 34, 5, 118, 76, 61, 23, 31, 68, 48]
forecast = 50

initial_inv = 0

setupcost = 450
holdingcost = 2
backordercost = 20
safetystock = 30
Big = sum(demand[t] for t in range(periods))

quantity = np.zeros(periods)

smoothing = 0.3 #exponential smoothing

# %%
#define function to call with each horizon option
def rolling_horizon(): #add more arguments for more flexibility, e.g. safetystock = None, smoothing constant, etc.
    #in case of using/changing initial_inv and forecast as global variable; otherwise must add to function arguments
    global initial_inv
    global forecast
    
    #define run horizon
    runs = periods-horizon+1
    
    #rolling over run horizon
    for k in range(runs): 
        m = gp.Model()
        lotsize = {}
        inventory ={}
        setup = {}
        
        # define decision variables
        for t in range(horizon):
            lotsize[t] = m.addVar()
            inventory[t] = m.addVar(obj=holdingcost)
            setup[t] = m.addVar(vtype=GRB.BINARY, obj=setupcost)
        
        # create constraints
        # initial inventory
        m.addConstr(inventory[0] == initial_inv+lotsize[0]-forecast)  
        
        # inventory balance
        for t in range(1,horizon):
            m.addConstr(inventory[t-1]+lotsize[t]-forecast == inventory[t])
        
        # logic constraint between lotsize and setup
        for t in range(horizon):
            m.addConstr(lotsize[t] <= Big*setup[t])

        # safety stock
        for t in range(horizon):
            m.addConstr(inventory[t] >= safetystock)
            
        # run model
        m.optimize()
        
        # update after each run: lotsize, starting inventory, forecast
        quantity[k] = lotsize[0].x #order of this period
        initial_inv = initial_inv + lotsize[0].x - demand[k] #inventory at the end of period after demand realization
        forecast = smoothing*demand[k] + (1-smoothing)*forecast #update forecast for next run
        m.dispose
        
    
    #repeat forecast for out-of-run period 
    for k in range(horizon-1):
        quantity[runs+k] = lotsize[k+1].x  


    # print result
    print("\n\nSolution:\n")
    print(quantity)
    
    cost = 0
    inv = 0
    for t in range(periods):
        if quantity[t] > 0:
            cost = cost+setupcost
            inv = inv+quantity[t]-demand[t]
        if inv > 0:
            cost=cost+holdingcost*inv
        else: cost=cost-backordercost*inv  
        
    print("Rolling Horizon Cost: "+str(cost))

# %%
horizon = 4
rolling_horizon()
# Out:
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (win64)
# Optimize a model with 12 rows, 12 columns and 23 nonzeros
# Model fingerprint: 0xc9a070b0
# Variable types: 8 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [2e+00, 5e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+01, 5e+01]
# Presolve removed 7 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 8 columns, 12 nonzeros
# Variable types: 5 continuous, 3 integer (3 binary)
#
# Root relaxation: objective 1.109143e+03, 3 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1109.14313    0    1          - 1109.14313      -     -    0s
# H    0     0                    1453.1799808 1109.14313  23.7%     -    0s
# H    0     0                    1316.3599616 1109.14313  15.7%     -    0s
#
# Cutting planes:
#   Flow cover: 1
#
# Explored 1 nodes (3 simplex iterations) in 0.01 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1316.36 1453.18
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.316359961616e+03, best bound 1.316359961616e+03, gap 0.0000%
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (win64)
# Optimize a model with 12 rows, 12 columns and 23 nonzeros
# Model fingerprint: 0xede230e7
# Variable types: 8 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [2e+00, 5e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+01, 1e+02]
# Presolve removed 7 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 8 columns, 12 nonzeros
# Variable types: 4 continuous, 4 integer (4 binary)
#
# Root relaxation: objective 1.035796e+03, 5 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1035.7959578 1035.79596  0.00%     -    0s
#
# Explored 0 nodes (5 simplex iterations) in 0.02 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1035.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.035795957778e+03, best bound 1.035795957778e+03, gap 0.0000%
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (win64)
# Optimize a model with 12 rows, 12 columns and 23 nonzeros
# Model fingerprint: 0x80521571
# Variable types: 8 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [2e+00, 5e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+01, 6e+01]
# Presolve removed 6 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 6 rows, 9 columns, 14 nonzeros
# Variable types: 5 continuous, 4 integer (4 binary)
#
# Root relaxation: objective 7.471616e+02, 3 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  747.16157    0    1          -  747.16157      -     -    0s
# H    0     0                    1070.9187681  747.16157  30.2%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.02 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1070.92
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.070918768141e+03, best bound 1.070918768141e+03, gap 0.0000%
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (win64)
# Optimize a model with 12 rows, 12 columns and 23 nonzeros
# Model fingerprint: 0xb40f7617
# Variable types: 8 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [2e+00, 5e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 6e+01]
# Presolve removed 7 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 8 columns, 12 nonzeros
# Variable types: 5 continuous, 3 integer (3 binary)
#
# Root relaxation: objective 1.180521e+03, 3 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1180.52080    0    1          - 1180.52080      -     -    0s
# H    0     0                    1506.5127334 1180.52080  21.6%     -    0s
# H    0     0                    1423.0254668 1180.52080  17.0%     -    0s
# H    0     0                    1384.3418223 1180.52080  14.7%     -    0s
#      0     0          -    0      1384.34182 1384.34182  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Flow cover: 2
#
# Explored 1 nodes (4 simplex iterations) in 0.02 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1384.34 1423.03 1506.51
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.384341822278e+03, best bound 1.384341822278e+03, gap 0.0000%
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (win64)
# Optimize a model with 12 rows, 12 columns and 23 nonzeros
# Model fingerprint: 0x681e52fd
# Variable types: 8 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [2e+00, 5e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+01, 7e+01]
# Presolve removed 6 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 6 rows, 9 columns, 14 nonzeros
# Variable types: 5 continuous, 4 integer (4 binary)
#
# Root relaxation: objective 7.118665e+02, 3 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  711.86646    0    1          -  711.86646      -     -    0s
# H    0     0                    1078.1810979  711.86646  34.0%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.02 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1078.18
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.078181097873e+03, best bound 1.078181097873e+03, gap 0.0000%
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (win64)
# Optimize a model with 12 rows, 12 columns and 23 nonzeros
# Model fingerprint: 0xbc1c1a05
# Variable types: 8 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [2e+00, 5e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+01, 7e+01]
# Presolve removed 7 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 8 columns, 12 nonzeros
# Variable types: 4 continuous, 4 integer (4 binary)
#
# Root relaxation: objective 8.683962e+02, 5 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     868.3961516  868.39615  0.00%     -    0s
#
# Explored 0 nodes (5 simplex iterations) in 0.01 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 868.396
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.683961516399e+02, best bound 8.683961516399e+02, gap 0.0000%
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (win64)
# Optimize a model with 12 rows, 12 columns and 23 nonzeros
# Model fingerprint: 0x3c9354f4
# Variable types: 8 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [2e+00, 5e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+01, 7e+01]
# Presolve removed 7 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 8 columns, 12 nonzeros
# Variable types: 5 continuous, 3 integer (3 binary)
#
# Root relaxation: objective 1.191079e+03, 3 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1191.07919    0    1          - 1191.07919      -     -    0s
# H    0     0                    1514.4018676 1191.07919  21.3%     -    0s
# H    0     0                    1438.8037351 1191.07919  17.2%     -    0s
# H    0     0                    1389.6012450 1191.07919  14.3%     -    0s
#      0     0          -    0      1389.60125 1389.60125  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Flow cover: 2
#
# Explored 1 nodes (4 simplex iterations) in 0.02 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1389.6 1438.8 1514.4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.389601245041e+03, best bound 1.389601245041e+03, gap 0.0000%
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (win64)
# Optimize a model with 12 rows, 12 columns and 23 nonzeros
# Model fingerprint: 0xef050c58
# Variable types: 8 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [2e+00, 5e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 7e+01]
# Presolve removed 7 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 8 columns, 12 nonzeros
# Variable types: 5 continuous, 3 integer (3 binary)
#
# Root relaxation: objective 1.223841e+03, 3 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1223.84115    0    1          - 1223.84115      -     -    0s
# H    0     0                    1538.8813073 1223.84115  20.5%     -    0s
# H    0     0                    1487.7626146 1223.84115  17.7%     -    0s
# H    0     0                    1405.9208715 1223.84115  13.0%     -    0s
#      0     0          -    0      1405.92087 1405.92087  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Flow cover: 2
#
# Explored 1 nodes (4 simplex iterations) in 0.02 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1405.92 1487.76 1538.88
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.405920871529e+03, best bound 1.405920871529e+03, gap 0.0000%
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (win64)
# Optimize a model with 12 rows, 12 columns and 23 nonzeros
# Model fingerprint: 0xd6e362a4
# Variable types: 8 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [2e+00, 5e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+01, 6e+01]
# Presolve removed 6 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 6 rows, 9 columns, 14 nonzeros
# Variable types: 5 continuous, 4 integer (4 binary)
#
# Root relaxation: objective 7.700668e+02, 3 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  770.06680    0    1          -  770.06680      -     -    0s
# H    0     0                    1093.2654816  770.06680  29.6%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.02 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1093.27
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.093265481599e+03, best bound 1.093265481599e+03, gap 0.0000%
#
#
# Solution:
#
# [160.18802747   0.           0.         114.38425727   0.
#    0.         159.62971138  84.15981324   0.         187.38417431
#    0.           0.        ]
# Rolling Horizon Cost: 8130.88900498729

# %%
horizon = 6
rolling_horizon()
# Out:
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (win64)
# Optimize a model with 18 rows, 18 columns and 35 nonzeros
# Model fingerprint: 0x8599969e
# Variable types: 12 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [2e+00, 5e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+01, 5e+01]
# Presolve removed 9 rows and 4 columns
# Presolve time: 0.02s
# Presolved: 9 rows, 14 columns, 22 nonzeros
# Variable types: 9 continuous, 5 integer (5 binary)
#
# Root relaxation: objective 1.300617e+03, 5 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1300.61701    0    3          - 1300.61701      -     -    0s
# H    0     0                    2473.7118406 1300.61701  47.4%     -    0s
# H    0     0                    1991.9942947 1300.61701  34.7%     -    0s
# H    0     0                    1887.4236811 1300.61701  31.1%     -    0s
#      0     0 1887.42368    0    2 1887.42368 1887.42368  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Implied bound: 4
#   Flow cover: 3
#
# Explored 1 nodes (11 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1887.42 1991.99 2473.71
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.887423681148e+03, best bound 1.887423681148e+03, gap 0.0000%
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (win64)
# Optimize a model with 18 rows, 18 columns and 35 nonzeros
# Model fingerprint: 0x22c2cb60
# Variable types: 12 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [2e+00, 5e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+01, 6e+01]
# Presolve removed 8 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 10 rows, 15 columns, 24 nonzeros
# Variable types: 9 continuous, 6 integer (6 binary)
#
# Root relaxation: objective 9.348206e+02, 5 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  934.82057    0    3          -  934.82057      -     -    0s
# H    0     0                    2117.3106995  934.82057  55.8%     -    0s
# H    0     0                    2049.5960063  934.82057  54.4%     -    0s
# H    0     0                    2006.9067058  934.82057  53.4%     -    0s
# H    0     0                    2004.5112700  934.82057  53.4%     -    0s
# H    0     0                    1780.1101290 1381.92662  22.4%     -    0s
#      0     0     cutoff    0      1780.11013 1780.11013  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Implied bound: 5
#   Clique: 1
#   Flow cover: 2
#
# Explored 1 nodes (11 simplex iterations) in 0.04 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 1780.11 2004.51 2006.91 ... 2117.31
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.780110128975e+03, best bound 1.780110128975e+03, gap 0.0000%
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (win64)
# Optimize a model with 18 rows, 18 columns and 35 nonzeros
# Model fingerprint: 0xc3a72509
# Variable types: 12 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [2e+00, 5e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 6e+01]
# Presolve removed 9 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 9 rows, 14 columns, 22 nonzeros
# Variable types: 9 continuous, 5 integer (5 binary)
#
# Root relaxation: objective 1.400030e+03, 5 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1400.03001    0    3          - 1400.03001      -     -    0s
# H    0     0                    2537.2788019 1400.03001  44.8%     -    0s
# H    0     0                    2140.3172044 1400.03001  34.6%     -    0s
#      0     0 1866.82709    0    2 2140.31720 1866.82709  12.8%     -    0s
# H    0     0                    2014.5576038 1866.82709  7.33%     -    0s
#      0     0 2014.55760    0    4 2014.55760 2014.55760  0.00%     -    0s
#
# Cutting planes:
#   Implied bound: 5
#   Flow cover: 2
#   Flow path: 2
#
# Explored 1 nodes (13 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2014.56 2140.32 2537.28
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.014557603762e+03, best bound 2.014557603762e+03, gap 0.0000%
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (win64)
# Optimize a model with 18 rows, 18 columns and 35 nonzeros
# Model fingerprint: 0x3b207b52
# Variable types: 12 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [2e+00, 5e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+01, 1e+02]
# Presolve removed 9 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 9 rows, 14 columns, 22 nonzeros
# Variable types: 8 continuous, 6 integer (6 binary)
#
# Root relaxation: objective 1.045618e+03, 4 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1045.61789    0    2          - 1045.61789      -     -    0s
# H    0     0                    1786.5576038 1045.61789  41.5%     -    0s
# H    0     0                    1703.2527651 1045.61789  38.6%     -    0s
# H    0     0                    1664.3258833 1290.67298  22.5%     -    0s
#      0     0          -    0      1664.32588 1664.32588  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Implied bound: 2
#   MIR: 1
#   Flow cover: 3
#   Flow path: 1
#
# Explored 1 nodes (6 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1664.33 1703.25 1786.56
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.664325883323e+03, best bound 1.664325883323e+03, gap 0.0000%
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (win64)
# Optimize a model with 18 rows, 18 columns and 35 nonzeros
# Model fingerprint: 0xe23669fb
# Variable types: 12 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [2e+00, 5e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+01, 7e+01]
# Presolve removed 8 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 10 rows, 15 columns, 24 nonzeros
# Variable types: 9 continuous, 6 integer (6 binary)
#
# Root relaxation: objective 9.162427e+02, 5 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  916.24268    0    3          -  916.24268      -     -    0s
# H    0     0                    2117.2032105  916.24268  56.7%     -    0s
# H    0     0                    2001.7354302  916.24268  54.2%     -    0s
# H    0     0                    1958.9386406  916.24268  53.2%     -    0s
#      0     0 1718.17984    0    1 1958.93864 1718.17984  12.3%     -    0s
# H    0     0                    1773.1654148 1718.17984  3.10%     -    0s
#      0     0 1773.16541    0    1 1773.16541 1773.16541  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Implied bound: 5
#   Clique: 1
#   Flow cover: 2
#   Flow path: 1
#
# Explored 1 nodes (11 simplex iterations) in 0.02 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 1773.17 1958.94 2001.74 2117.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.773165414803e+03, best bound 1.773165414803e+03, gap 0.0000%
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (win64)
# Optimize a model with 18 rows, 18 columns and 35 nonzeros
# Model fingerprint: 0x05076832
# Variable types: 12 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [2e+00, 5e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+01, 8e+01]
# Presolve removed 9 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 9 rows, 14 columns, 22 nonzeros
# Variable types: 8 continuous, 6 integer (6 binary)
#
# Root relaxation: objective 8.245374e+02, 4 iterations, 0.00 seconds
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  824.53738    0    2          -  824.53738      -     -    0s
# H    0     0                    1630.5576038  824.53738  49.4%     -    0s
# H    0     0                    1412.0782328  824.53738  41.6%     -    0s
#      0     0     cutoff    0      1412.07823 1412.07823  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Implied bound: 2
#   MIR: 1
#   Flow cover: 3
#
# Explored 1 nodes (5 simplex iterations) in 0.02 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1412.08 1630.56
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.412078232808e+03, best bound 1.412078232808e+03, gap 0.0000%
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (win64)
# Optimize a model with 18 rows, 18 columns and 35 nonzeros
# Model fingerprint: 0xfe7bd183
# Variable types: 12 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [2e+00, 5e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+01, 6e+01]
# Presolve removed 9 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 9 rows, 14 columns, 22 nonzeros
# Variable types: 9 continuous, 5 integer (5 binary)
#
# Root relaxation: objective 1.395629e+03, 5 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1395.62860    0    3          - 1395.62860      -     -    0s
# H    0     0                    2534.4644403 1395.62860  44.9%     -    0s
# H    0     0                    2209.2859204 1395.62860  36.8%     -    0s
# H    0     0                    2133.7503608 1395.62860  34.6%     -    0s
#      0     0 1863.08995    0    2 2133.75036 1863.08995  12.7%     -    0s
# H    0     0                    2008.9288807 1863.08995  7.26%     -    0s
#      0     0 2008.92888    0    2 2008.92888 2008.92888  0.00%     -    0s
#
# Cutting planes:
#   Implied bound: 5
#   Flow cover: 2
#   Flow path: 1
#
# Explored 1 nodes (12 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 2008.93 2133.75 2209.29 2534.46
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.008928880663e+03, best bound 2.008928880663e+03, gap 0.0000%
#
#
# Solution:
#
# [107.89548452   0.         175.78348065   0.           0.
#    0.         212.59281923   0.           0.         187.23222017
#    0.           0.        ]
# Rolling Horizon Cost: 7757.668393309542

# %%
horizon = 8
rolling_horizon()
# Out:
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (win64)
# Optimize a model with 24 rows, 24 columns and 47 nonzeros
# Model fingerprint: 0x0e146a94
# Variable types: 16 continuous, 8 integer (8 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [2e+00, 5e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+01, 5e+01]
# Presolve removed 11 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 13 rows, 20 columns, 32 nonzeros
# Variable types: 13 continuous, 7 integer (7 binary)
#
# Root relaxation: objective 1.491379e+03, 7 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1491.37908    0    5          - 1491.37908      -     -    0s
# H    0     0                    3493.7118406 1491.37908  57.3%     -    0s
# H    0     0                    3053.1298164 1491.37908  51.2%     -    0s
# H    0     0                    2802.8530676 1491.37908  46.8%     -    0s
#      0     0 2227.79601    0    4 2802.85307 2227.79601  20.5%     -    0s
# H    0     0                    2739.4179758 2227.79601  18.7%     -    0s
# H    0     0                    2561.9942947 2227.79601  13.0%     -    0s
#      0     0 2423.61514    0    6 2561.99429 2423.61514  5.40%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Implied bound: 5
#   MIR: 4
#   Flow cover: 5
#   Flow path: 4
#   Relax-and-lift: 4
#
# Explored 1 nodes (19 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 2561.99 2739.42 2802.85 ... 3493.71
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.561994294672e+03, best bound 2.561994294672e+03, gap 0.0000%
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (win64)
# Optimize a model with 24 rows, 24 columns and 47 nonzeros
# Model fingerprint: 0x3a03b124
# Variable types: 16 continuous, 8 integer (8 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [2e+00, 5e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 6e+01]
# Presolve removed 11 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 13 rows, 20 columns, 32 nonzeros
# Variable types: 13 continuous, 7 integer (7 binary)
#
# Root relaxation: objective 1.535555e+03, 7 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1535.55483    0    5          - 1535.55483      -     -    0s
# H    0     0                    3518.3982884 1535.55483  56.4%     -    0s
# H    0     0                    3184.7908715 1535.55483  51.8%     -    0s
# H    0     0                    3181.1977179 1535.55483  51.7%     -    0s
# H    0     0                    2619.5960063 1535.55483  41.4%     -    0s
#      0     0 2311.52487    0    4 2619.59601 2311.52487  11.8%     -    0s
#      0     0 2395.69338    0    6 2619.59601 2395.69338  8.55%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Implied bound: 4
#   MIR: 2
#   Flow cover: 3
#   Flow path: 4
#   Relax-and-lift: 4
#
# Explored 1 nodes (18 simplex iterations) in 0.04 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 2619.6 3181.2 3184.79 3518.4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.619596006271e+03, best bound 2.619596006271e+03, gap 0.0000%
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (win64)
# Optimize a model with 24 rows, 24 columns and 47 nonzeros
# Model fingerprint: 0x9fd71bf5
# Variable types: 16 continuous, 8 integer (8 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [2e+00, 5e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+01, 6e+01]
# Presolve removed 10 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 14 rows, 21 columns, 34 nonzeros
# Variable types: 13 continuous, 8 integer (8 binary)
#
# Root relaxation: objective 1.192606e+03, 7 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1192.60571    0    5          - 1192.60571      -     -    0s
# H    0     0                    3163.9174897 1192.60571  62.3%     -    0s
# H    0     0                    3038.1578890 1192.60571  60.7%     -    0s
# H    0     0                    2839.6770903 1192.60571  58.0%     -    0s
#      0     0 2291.58820    0    5 2839.67709 2291.58820  19.3%     -    0s
# H    0     0                    2819.9942947 2291.58820  18.7%     -    0s
# H    0     0                    2641.1962915 2291.58820  13.2%     -    0s
# H    0     0                    2568.4750934 2291.58820  10.8%     -    0s
# H    0     0                    2515.4366909 2291.58820  8.90%     -    0s
#      0     0 2515.43669    0    3 2515.43669 2515.43669  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Implied bound: 7
#   Clique: 1
#   MIR: 2
#   Flow cover: 5
#   Flow path: 3
#
# Explored 1 nodes (22 simplex iterations) in 0.04 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 2515.44 2568.48 2641.2 ... 3163.92
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.515436690910e+03, best bound 2.515436690910e+03, gap 0.0000%
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (win64)
# Optimize a model with 24 rows, 24 columns and 47 nonzeros
# Model fingerprint: 0xe981246b
# Variable types: 16 continuous, 8 integer (8 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [2e+00, 5e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 6e+01]
# Presolve removed 11 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 13 rows, 20 columns, 32 nonzeros
# Variable types: 13 continuous, 7 integer (7 binary)
#
# Root relaxation: objective 1.586191e+03, 7 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1586.19134    0    5          - 1586.19134      -     -    0s
# H    0     0                    3546.6951613 1586.19134  55.3%     -    0s
# H    0     0                    3335.7075270 1586.19134  52.4%     -    0s
# H    0     0                    3135.6220431 1586.19134  49.4%     -    0s
# H    0     0                    2685.6220431 1586.19134  40.9%     -    0s
#      0     0 2401.01463    0    6 2685.62204 2401.01463  10.6%     -    0s
#      0     0 2401.64008    0    6 2685.62204 2401.64008  10.6%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Implied bound: 4
#   MIR: 2
#   Flow cover: 4
#   Flow path: 4
#   Relax-and-lift: 4
#
# Explored 1 nodes (17 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 2685.62 3135.62 3335.71 3546.7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.685622043073e+03, best bound 2.685622043073e+03, gap 0.0000%
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (win64)
# Optimize a model with 24 rows, 24 columns and 47 nonzeros
# Model fingerprint: 0xb72ae70f
# Variable types: 16 continuous, 8 integer (8 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [2e+00, 5e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+01, 1e+02]
# Presolve removed 11 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 13 rows, 20 columns, 32 nonzeros
# Variable types: 12 continuous, 8 integer (8 binary)
#
# Root relaxation: objective 1.263143e+03, 6 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1263.14304    0    4          - 1263.14304      -     -    0s
# H    0     0                    2877.3903226 1263.14304  56.1%     -    0s
# H    0     0                    2738.3172044 1263.14304  53.9%     -    0s
# H    0     0                    2533.3525269 1263.14304  50.1%     -    0s
#      0     0 2194.29368    0    2 2533.35253 2194.29368  13.4%     -    0s
# H    0     0                    2401.2391399 2194.29368  8.62%     -    0s
# H    0     0                    2295.2769356 2194.29368  4.40%     -    0s
#      0     0 2295.27694    0    4 2295.27694 2295.27694  0.00%     -    0s
# Cutting planes:
#   Implied bound: 5
#   MIR: 1
#   Flow cover: 4
#   Flow path: 2
#
# Explored 1 nodes (15 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 2295.28 2401.24 2533.35 ... 2877.39
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.295276935555e+03, best bound 2.295276935555e+03, gap 0.0000%
#
#
# Solution:
#
# [ 55.61017776 130.62853068   0.         149.14843646   0.
#    0.         115.55793011   0.           0.         158.94330646
#    0.           0.        ]
# Rolling Horizon Cost: 6702.074886715781
