# %%
# Travelling salesman - 120 cities

import numpy as np
import pandas as pd

cities = 120

di = pd.read_excel("gr120.xlsx",sheet_name="DistanceMatrix")
distance=di.values

for i in range(cities):
    distance[i,i] = 10000

# determine optimal solution

import gurobipy as gp
from gurobipy import GRB

m = gp.Model("Travelling Salesman Problem")

# Create variables
travel = {}
delivery = {}
for i in range(cities):
   for j in range(cities):
      travel[i,j] = m.addVar(vtype=GRB.BINARY, obj=distance[i,j])
      delivery[i,j] = m.addVar()

# departure constraints
for i in range(cities):
   m.addConstr(sum(travel[i,j] for j in range(cities)) == 1)
    
# arrival constraints
for j in range(cities):
   m.addConstr(sum(travel[i,j] for i in range(cities)) == 1)

# flow constraint
m.addConstr(sum(delivery[0,i] for i in range(cities)) == cities-1)
for i in range(1,cities):
   m.addConstr(sum(delivery[j,i] for j in range(cities))-sum(delivery[i,j] for j in range(cities)) == 1) 

# Logic 
for i in range(cities):
  for j in range(1,cities):
    if i != j:
        m.addConstr(travel[i,j] <= delivery[i,j])
        m.addConstr(delivery[i,j] <= (cities-1)*travel[i,j])
        
for i in range(1,cities):
    m.addConstr(delivery[i,0] == 0)

#m.Params.TimeLimit=60
#m.Params.MIPGap=0.1

m.optimize()

print("Objective: "+str(m.objVal))

m.dispose()
# Out:
# Using license file C:\Users\sminn\gurobi.lic
# Academic license - for non-commercial use only
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (win64)
# Optimize a model with 28801 rows, 28800 columns and 114005 nonzeros
# Model fingerprint: 0x9ff62e8c
# Variable types: 14400 continuous, 14400 integer (14400 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+01, 1e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Presolve removed 119 rows and 254 columns
# Presolve time: 0.42s
# Presolved: 28682 rows, 28546 columns, 113737 nonzeros
# Variable types: 14161 continuous, 14385 integer (14385 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.16s
#
# Solved with primal simplex
#
# Root relaxation: objective 6.035191e+03, 28963 iterations, 1.60 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6035.19149    0  229          - 6035.19149      -     -    3s
#      0     0 6461.24644    0  255          - 6461.24644      -     -    7s
# H    0     0                    8864.0000000 6461.24644  27.1%     -   18s
#      0     0 6740.47073    0  267 8864.00000 6740.47073  24.0%     -   18s
# H    0     0                    7390.0000000 6740.47073  8.79%     -   30s
# H    0     0                    6961.0000000 6740.47073  3.17%     -   31s
#      0     0 6797.77412    0  264 6961.00000 6797.77412  2.34%     -   31s
#      0     0 6797.77412    0  263 6961.00000 6797.77412  2.34%     -   32s
#      0     0 6797.77412    0  263 6961.00000 6797.77412  2.34%     -   32s
#      0     0 6851.91521    0  216 6961.00000 6851.91521  1.57%     -   34s
#      0     0 6851.91521    0  230 6961.00000 6851.91521  1.57%     -   35s
#      0     0 6851.91521    0  262 6961.00000 6851.91521  1.57%     -   35s
#      0     0 6851.91521    0  264 6961.00000 6851.91521  1.57%     -   35s
#      0     0 6851.91521    0  266 6961.00000 6851.91521  1.57%     -   35s
#      0     0 6852.35944    0  259 6961.00000 6852.35944  1.56%     -   35s
#      0     0 6852.35944    0  259 6961.00000 6852.35944  1.56%     -   35s
#      0     0 6865.15848    0  254 6961.00000 6865.15848  1.38%     -   36s
#      0     0 6865.27102    0  274 6961.00000 6865.27102  1.38%     -   36s
#      0     0 6893.19855    0  226 6961.00000 6893.19855  0.97%     -   36s
#      0     0 6893.28061    0  231 6961.00000 6893.28061  0.97%     -   36s
#      0     0 6899.37793    0  217 6961.00000 6899.37793  0.89%     -   37s
#      0     0 6899.37793    0  226 6961.00000 6899.37793  0.89%     -   37s
#      0     0 6899.37793    0  259 6961.00000 6899.37793  0.89%     -   37s
#      0     0 6899.37793    0  285 6961.00000 6899.37793  0.89%     -   37s
#      0     0 6899.37793    0  272 6961.00000 6899.37793  0.89%     -   38s
#      0     0 6899.83266    0  280 6961.00000 6899.83266  0.88%     -   38s
#      0     0 6899.83266    0  277 6961.00000 6899.83266  0.88%     -   38s
#      0     0 6903.12224    0  263 6961.00000 6903.12224  0.83%     -   38s
#      0     0 6903.12229    0  235 6961.00000 6903.12229  0.83%     -   38s
#      0     0 6906.08237    0  288 6961.00000 6906.08237  0.79%     -   38s
#      0     0 6906.08237    0  233 6961.00000 6906.08237  0.79%     -   39s
#      0     2 6908.08237    0  233 6961.00000 6908.08237  0.76%     -   39s
#     56    48 6911.67797   14  165 6961.00000 6908.08237  0.76%  85.8   40s
# H  712   433                    6956.0000000 6912.10169  0.63%  37.1   42s
#   1052   590 6928.60147   13  267 6956.00000 6917.05276  0.56%  35.8   45s
#   1105   627 6936.03647   15  284 6956.00000 6935.74594  0.29%  41.9   50s
#   1137   648 6938.93969   28  276 6956.00000 6938.93969  0.25%  40.7   55s
#   1164   668 6938.98182   37  138 6956.00000 6938.98182  0.24%  55.0   60s
# H 1192   651                    6955.0000000 6939.00000  0.23%  57.2   62s
# * 1229   633              49    6951.0000000 6939.05861  0.17%  57.6   63s
# H 1360   585                    6942.0000000 6939.05861  0.04%  56.5   63s
#
# Cutting planes:
#   Gomory: 13
#   Cover: 1
#   Implied bound: 1
#   Projected implied bound: 1
#   MIR: 35
#   Flow cover: 169
#   Flow path: 7
#   GUB cover: 1
#   Inf proof: 4
#   Zero half: 28
#   Network: 19
#
# Explored 1479 nodes (155770 simplex iterations) in 63.84 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 6942 6951 6955 ... 8864
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.942000000000e+03, best bound 6.942000000000e+03, gap 0.0000%
# Objective: 6942.0
